# %%
from tabulate import tabulate

f = open("input.txt", "r")

workflows = {}

for line in f:
    if line =='\n':
        break
    line = line.replace('\n', '')
    [name, workflow] = line.split('{')
    workflow = workflow.replace('}', '')
    rules = workflow.split(',')
    workflow = []
    for rule in rules:
        if ':' in rule:
            [condition, destination] = rule.split(':')
            if '<' in condition:
                [rating, threshold] = condition.split('<')
                operator = '<'
            elif '>' in condition:
                [rating, threshold] = condition.split('>')
                operator = '>'
            else:
                raise ValueError
            threshold = int(threshold)
            workflow.append({"operator": operator, "rating": rating, "threshold": threshold, "destination": destination})
        else:
            destination = rule
            workflow.append({"destination": destination})
    workflows[name] = workflow

print(tabulate(workflows, headers="keys", tablefmt="rounded_grid"))

parts = []

for line in f:
    line = line.replace('\n', '').replace('{', '').replace('}', '')
    [x, m, a, s] = [int(rating.split('=')[1]) for rating in line.split(',')]
    parts.append({"x": x, "m": m, "a": a, "s": s})

print(tabulate(parts, headers="keys", tablefmt="rounded_grid"))

total = 0

for part_nb, part in enumerate(parts):
    processing_part = True
    workflow_name = "in"
    workflow = workflows[workflow_name]
    while processing_part:
        print(f"Processing part number {part_nb}")
        print(f"Workflow {workflow_name}")
        for rule in workflow:
            destination = rule["destination"]
            if "rating" not in rule:
                condition = True
            else:
                operator = rule["operator"]
                rating = rule["rating"]
                threshold = rule["threshold"]
                rating = part[rating]
                match operator:
                    case '<':
                        condition = (rating < threshold)
                    case '>':
                        condition = (rating > threshold)
                    case _:
                        raise
            if condition:
                if destination == 'A':
                    total += sum(part.values())
                    processing_part = False
                    print(f"Part number {part_nb} accepted")
                    break
                elif destination == 'R':
                    processing_part = False
                    print(f"Part number {part_nb} rejected")
                    break
                else:
                    workflow_name = destination
                    workflow = workflows[workflow_name]
                    break

print(total)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────── ...
# │ mn                                                                      │ jcj                                                                     │ lm                                                                      │ hfm                                                                     │ gvr                                                                       │ xd                                                                      │ gms                                                                       │ nsv                                                                     │ gz                                                                      │ lc                                                                      │ qc                                                                      │ ndl                                                                      │ vfz                                                                       │ ld                                                                        │ jlj                                                                     │ nn                                                                       │ kfq                                                                     │ xl                                                                        │ tz                                                                        │ gf                                                                        │ zf                                                                       │ rkm                                                                       │ sh                                                                      │ zm                                                                      │ fd                                                                      │ qr                                                                      │ tvj                                                                       │ frn                                                                       │ sf                                                                      │ tx                                                                        │ mrf                                                                     │ jkr                                                                       │ sc                                                                      │ tzc                                                                     │ cml                                                                     │ rp                                                                      │ cmn                                                                     │ dsf                                                                    │ zvv                                                                      │ sb                                                                        │ xk                                                                     │ jf                                                                        │ ktt                                                                    │ lvj                                                                       │ fsj                                                                     │ vn                                                                        │ nv                                                                      │ rf                                                                       │ rh                                                                      │ dq                                                                       │ qpl                                                                      │ mz                                                                        │ ggm                                                                     │ vf                                     ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '<', 'rating': 's', 'threshold': 3661, 'destination': 'A'} │ {'operator': '<', 'rating': 'x', 'threshold': 2501, 'destination': 'R'} │ {'operator': '>', 'rating': 's', 'threshold': 1017, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 661, 'destination': 'gm'} │ {'operator': '<', 'rating': 'x', 'threshold': 1627, 'destination': 'jlj'} │ {'operator': '<', 'rating': 'a', 'threshold': 3515, 'destination': 'A'} │ {'operator': '<', 'rating': 'a', 'threshold': 3153, 'destination': 'tbr'} │ {'operator': '<', 'rating': 'a', 'threshold': 1742, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 1839, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 2328, 'destination': 'A'} │ {'operator': '<', 'rating': 'x', 'threshold': 1673, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3705, 'destination': 'tr'} │ {'operator': '<', 'rating': 'a', 'threshold': 3535, 'destination': 'tpv'} │ {'operator': '<', 'rating': 'x', 'threshold': 2662, 'destination': 'kdb'} │ {'operator': '>', 'rating': 'a', 'threshold': 2672, 'destination': 'A'} │ {'operator': '<', 'rating': 'a', 'threshold': 2837, 'destination': 'mm'} │ {'operator': '>', 'rating': 'm', 'threshold': 3404, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 1669, 'destination': 'A'}   │ {'operator': '>', 'rating': 'x', 'threshold': 2729, 'destination': 'A'}   │ {'operator': '<', 'rating': 'a', 'threshold': 1839, 'destination': 'jjv'} │ {'operator': '<', 'rating': 'x', 'threshold': 2559, 'destination': 'R'}  │ {'operator': '<', 'rating': 'x', 'threshold': 2920, 'destination': 'qpl'} │ {'operator': '<', 'rating': 's', 'threshold': 950, 'destination': 'R'}  │ {'operator': '<', 'rating': 'a', 'threshold': 3311, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 1125, 'destination': 'A'} │ {'operator': '>', 'rating': 'a', 'threshold': 1507, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'threshold': 1336, 'destination': 'gqp'} │ {'operator': '<', 'rating': 'x', 'threshold': 3485, 'destination': 'vfx'} │ {'operator': '<', 'rating': 'x', 'threshold': 2428, 'destination': 'R'} │ {'operator': '<', 'rating': 'a', 'threshold': 835, 'destination': 'R'}    │ {'operator': '>', 'rating': 'x', 'threshold': 1667, 'destination': 'A'} │ {'operator': '<', 'rating': 'm', 'threshold': 2927, 'destination': 'kxc'} │ {'operator': '>', 'rating': 's', 'threshold': 1038, 'destination': 'A'} │ {'operator': '>', 'rating': 'm', 'threshold': 2622, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 2768, 'destination': 'R'} │ {'operator': '<', 'rating': 'a', 'threshold': 3056, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 1877, 'destination': 'A'} │ {'operator': '>', 'rating': 'm', 'threshold': 720, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 1686, 'destination': 'df'} │ {'operator': '<', 'rating': 'a', 'threshold': 157, 'destination': 'xhk'}  │ {'operator': '>', 'rating': 'a', 'threshold': 390, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 441, 'destination': 'zvv'}  │ {'operator': '>', 'rating': 'a', 'threshold': 231, 'destination': 'R'} │ {'operator': '>', 'rating': 'x', 'threshold': 3711, 'destination': 'zpn'} │ {'operator': '>', 'rating': 'x', 'threshold': 3517, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 1525, 'destination': 'jn'}  │ {'operator': '>', 'rating': 's', 'threshold': 3581, 'destination': 'R'} │ {'operator': '>', 'rating': 'm', 'threshold': 2639, 'destination': 'A'}  │ {'operator': '>', 'rating': 'a', 'threshold': 813, 'destination': 'R'}  │ {'operator': '<', 'rating': 'x', 'threshold': 2671, 'destination': 'rj'} │ {'operator': '<', 'rating': 's', 'threshold': 3540, 'destination': 'mv'} │ {'operator': '<', 'rating': 'a', 'threshold': 2856, 'destination': 'R'}   │ {'operator': '<', 'rating': 's', 'threshold': 2962, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '>', 'rating': 's', 'threshold': 3705, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'threshold': 516, 'destination': 'R'}  │ {'operator': '>', 'rating': 'a', 'threshold': 470, 'destination': 'R'}  │ {'destination': 'fck'}                                                  │ {'destination': 'R'}                                                      │ {'operator': '<', 'rating': 'x', 'threshold': 1086, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 1274, 'destination': 'hgz'} │ {'operator': '>', 'rating': 'x', 'threshold': 142, 'destination': 'R'}  │ {'operator': '>', 'rating': 'x', 'threshold': 1848, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 3513, 'destination': 'A'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'a', 'threshold': 3474, 'destination': 'zr'} │ {'destination': 'R'}                                                      │ {'operator': '>', 'rating': 'x', 'threshold': 2851, 'destination': 'A'}   │ {'destination': 'R'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 3088, 'destination': 'zj'} │ {'operator': '>', 'rating': 'm', 'threshold': 3071, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3278, 'destination': 'kdg'} │ {'operator': '>', 'rating': 'a', 'threshold': 1540, 'destination': 'A'}   │ {'operator': '>', 'rating': 's', 'threshold': 3144, 'destination': 'tfn'} │ {'operator': '<', 'rating': 'a', 'threshold': 3507, 'destination': 'bg'} │ {'destination': 'hq'}                                                     │ {'operator': '<', 'rating': 's', 'threshold': 1280, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 3539, 'destination': 'R'} │ {'operator': '>', 'rating': 'm', 'threshold': 1688, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 236, 'destination': 'R'}  │ {'destination': 'tv'}                                                     │ {'destination': 'vgj'}                                                    │ {'operator': '>', 'rating': 's', 'threshold': 1024, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3130, 'destination': 'skj'} │ {'operator': '<', 'rating': 'a', 'threshold': 3699, 'destination': 'R'} │ {'operator': '>', 'rating': 'a', 'threshold': 2049, 'destination': 'R'}   │ {'destination': 'R'}                                                    │ {'operator': '<', 'rating': 's', 'threshold': 1490, 'destination': 'R'} │ {'destination': 'R'}                                                    │ {'destination': 'A'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 103, 'destination': 'A'}  │ {'destination': 'A'}                                                   │ {'operator': '<', 'rating': 'a', 'threshold': 1613, 'destination': 'fc'} │ {'operator': '<', 'rating': 'x', 'threshold': 1408, 'destination': 'qdf'} │ {'operator': '<', 'rating': 'x', 'threshold': 198, 'destination': 'R'} │ {'operator': '>', 'rating': 'a', 'threshold': 2404, 'destination': 'jqg'} │ {'destination': 'R'}                                                   │ {'operator': '<', 'rating': 'x', 'threshold': 3392, 'destination': 'tlf'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'x', 'threshold': 1345, 'destination': 'zjl'} │ {'operator': '<', 'rating': 's', 'threshold': 3340, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3257, 'destination': 'zm'} │ {'operator': '>', 'rating': 's', 'threshold': 3042, 'destination': 'A'} │ {'destination': 'qz'}                                                    │ {'destination': 'A'}                                                     │ {'operator': '>', 'rating': 'a', 'threshold': 3430, 'destination': 'pvc'} │ {'operator': '>', 'rating': 'x', 'threshold': 2214, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '<', 'rating': 'm', 'threshold': 1698, 'destination': 'R'} │ {'destination': 'A'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 159, 'destination': 'A'}  │                                                                         │                                                                           │ {'destination': 'R'}                                                    │ {'destination': 'mkg'}                                                    │ {'destination': 'dvh'}                                                  │ {'destination': 'R'}                                                    │ {'destination': 'R'}                                                    │                                                                         │ {'operator': '<', 'rating': 'x', 'threshold': 1760, 'destination': 'pl'} │                                                                           │ {'operator': '<', 'rating': 'm', 'threshold': 3657, 'destination': 'gt'}  │                                                                         │ {'operator': '>', 'rating': 'm', 'threshold': 1332, 'destination': 'zf'} │ {'destination': 'nh'}                                                   │ {'destination': 'pm'}                                                     │ {'operator': '<', 'rating': 'x', 'threshold': 2269, 'destination': 'ttv'} │ {'operator': '<', 'rating': 'x', 'threshold': 1424, 'destination': 'gpj'} │ {'operator': '>', 'rating': 'a', 'threshold': 3813, 'destination': 'A'}  │                                                                           │ {'operator': '>', 'rating': 'a', 'threshold': 1876, 'destination': 'A'} │ {'destination': 'R'}                                                    │ {'destination': 'A'}                                                    │ {'destination': 'R'}                                                    │                                                                           │                                                                           │ {'operator': '<', 'rating': 's', 'threshold': 385, 'destination': 'R'}  │ {'destination': 'ct'}                                                     │ {'destination': 'R'}                                                    │ {'destination': 'sh'}                                                     │                                                                         │ {'destination': 'A'}                                                    │                                                                         │                                                                         │ {'destination': 'mxg'}                                                  │                                                                        │ {'destination': 'nnt'}                                                   │ {'operator': '<', 'rating': 'm', 'threshold': 1174, 'destination': 'ff'}  │ {'operator': '>', 'rating': 'a', 'threshold': 189, 'destination': 'A'} │ {'operator': '>', 'rating': 'a', 'threshold': 1410, 'destination': 'bvc'} │                                                                        │ {'destination': 'R'}                                                      │                                                                         │ {'operator': '<', 'rating': 's', 'threshold': 1431, 'destination': 'vh'}  │ {'destination': 'A'}                                                    │ {'destination': 'jg'}                                                    │ {'operator': '>', 'rating': 's', 'threshold': 2781, 'destination': 'A'} │                                                                          │                                                                          │ {'operator': '<', 'rating': 'x', 'threshold': 2330, 'destination': 'ftt'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'a', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'destination': 'A'}                                                    │                                                                         │ {'destination': 'R'}                                                    │                                                                         │                                                                           │                                                                         │                                                                           │                                                                         │                                                                         │                                                                         │                                                                         │ {'destination': 'R'}                                                     │                                                                           │ {'destination': 'A'}                                                      │                                                                         │ {'destination': 'tn'}                                                    │                                                                         │                                                                           │ {'destination': 'tkd'}                                                    │ {'destination': 'ztz'}                                                    │ {'destination': 'xsf'}                                                   │                                                                           │ {'destination': 'A'}                                                    │                                                                         │                                                                         │                                                                         │                                                                           │                                                                           │ {'destination': 'R'}                                                    │                                                                           │                                                                         │                                                                           │                                                                         │                                                                         │                                                                         │                                                                         │                                                                         │                                                                        │                                                                          │ {'destination': 'zp'}                                                     │ {'destination': 'A'}                                                   │ {'destination': 'mb'}                                                     │                                                                        │                                                                           │                                                                         │ {'destination': 'gf'}                                                     │                                                                         │                                                                          │ {'destination': 'R'}                                                    │                                                                          │                                                                          │ {'destination': 'pg'}                                                     │                                                                         │ {'destination': 'A'}                   ...
# ╰─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────── ...
# ╭──────┬──────┬──────┬──────╮
# │    x │    m │    a │    s │
# ├──────┼──────┼──────┼──────┤
# │ 1353 │ 3037 │ 1714 │ 2238 │
# ├──────┼──────┼──────┼──────┤
# │  608 │ 1974 │ 1157 │ 1316 │
# ├──────┼──────┼──────┼──────┤
# │ 1225 │ 1440 │   80 │ 1364 │
# ├──────┼──────┼──────┼──────┤
# │    4 │ 1245 │  948 │  147 │
# ├──────┼──────┼──────┼──────┤
# │   30 │ 2538 │ 1716 │  823 │
# ├──────┼──────┼──────┼──────┤
# │  626 │  128 │ 1042 │  519 │
# ├──────┼──────┼──────┼──────┤
# │  182 │   87 │ 1114 │  123 │
# ├──────┼──────┼──────┼──────┤
# │ 3097 │ 2262 │   60 │  505 │
# ├──────┼──────┼──────┼──────┤
# │  700 │ 1844 │   30 │  185 │
# ├──────┼──────┼──────┼──────┤
# │   88 │ 2157 │   39 │ 1966 │
# ├──────┼──────┼──────┼──────┤
# │  703 │  305 │  704 │ 1759 │
# ├──────┼──────┼──────┼──────┤
# │  400 │ 1034 │ 1947 │ 1104 │
# ├──────┼──────┼──────┼──────┤
# │   27 │ 1959 │   87 │ 1404 │
# ├──────┼──────┼──────┼──────┤
# │ 1654 │  351 │ 1498 │  605 │
# ├──────┼──────┼──────┼──────┤
# │  546 │  629 │ 1120 │  776 │
# ├──────┼──────┼──────┼──────┤
# │ 1467 │ 1402 │ 2819 │  652 │
# ├──────┼──────┼──────┼──────┤
# │  395 │  710 │   37 │  426 │
# ├──────┼──────┼──────┼──────┤
# │  165 │  986 │ 3316 │ 3628 │
# ├──────┼──────┼──────┼──────┤
# │  119 │ 2580 │  477 │ 1134 │
# ├──────┼──────┼──────┼──────┤
# │    4 │   44 │  760 │  216 │
# ├──────┼──────┼──────┼──────┤
# │ 1633 │ 3445 │ 1494 │ 1396 │
# ├──────┼──────┼──────┼──────┤
# │  670 │ 1082 │  708 │  290 │
# ├──────┼──────┼──────┼──────┤
# │ 2566 │ 2148 │   99 │ 3038 │
# ├──────┼──────┼──────┼──────┤
# │  107 │ 1631 │    2 │  293 │
# ├──────┼──────┼──────┼──────┤
# │ 2292 │  984 │ 3360 │  124 │
# ├──────┼──────┼──────┼──────┤
# │ 2624 │  501 │ 1111 │ 1114 │
# ├──────┼──────┼──────┼──────┤
# │ 1217 │ 1508 │ 2880 │ 1744 │
# ├──────┼──────┼──────┼──────┤
# │ 1705 │  623 │  271 │    3 │
# ├──────┼──────┼──────┼──────┤
# │ 3043 │   25 │ 2091 │ 1193 │
# ├──────┼──────┼──────┼──────┤
# │ 1566 │   53 │  418 │    6 │
# ├──────┼──────┼──────┼──────┤
# │ 1438 │  255 │ 1726 │ 1265 │
# ├──────┼──────┼──────┼──────┤
# │   77 │  326 │  486 │  795 │
# ├──────┼──────┼──────┼──────┤
# │   31 │  836 │  596 │  327 │
# ├──────┼──────┼──────┼──────┤
# │  477 │ 1056 │ 1680 │ 2268 │
# ├──────┼──────┼──────┼──────┤
# │  898 │  647 │   66 │  244 │
# ├──────┼──────┼──────┼──────┤
# │ 3627 │ 2071 │   96 │  625 │
# ├──────┼──────┼──────┼──────┤
# │ 1149 │ 1690 │   79 │  237 │
# ├──────┼──────┼──────┼──────┤
# │  710 │  847 │ 2859 │  618 │
# ├──────┼──────┼──────┼──────┤
# │   20 │ 1793 │ 1189 │  207 │
# ├──────┼──────┼──────┼──────┤
# │   10 │  337 │ 1006 │  127 │
# ├──────┼──────┼──────┼──────┤
# │  184 │  113 │  945 │ 1385 │
# ├──────┼──────┼──────┼──────┤
# │  913 │  448 │  458 │  384 │
# ├──────┼──────┼──────┼──────┤
# │ 1236 │  181 │ 1480 │  273 │
# ├──────┼──────┼──────┼──────┤
# │ 3386 │    4 │  297 │ 2045 │
# ├──────┼──────┼──────┼──────┤
# │  106 │  846 │ 1723 │  415 │
# ├──────┼──────┼──────┼──────┤
# │ 1888 │ 1035 │  375 │   17 │
# ├──────┼──────┼──────┼──────┤
# │  496 │ 3286 │ 1123 │  225 │
# ├──────┼──────┼──────┼──────┤
# │ 1322 │  104 │  670 │  584 │
# ├──────┼──────┼──────┼──────┤
# │  544 │  293 │   14 │  350 │
# ├──────┼──────┼──────┼──────┤
# │ 3419 │  469 │ 3627 │  594 │
# ├──────┼──────┼──────┼──────┤
# │  447 │   78 │  518 │  479 │
# ├──────┼──────┼──────┼──────┤
# │ 2602 │  700 │  536 │ 1356 │
# ├──────┼──────┼──────┼──────┤
# │  956 │   95 │ 1599 │  492 │
# ├──────┼──────┼──────┼──────┤
# │    1 │ 1709 │  117 │  141 │
# ├──────┼──────┼──────┼──────┤
# │   83 │ 1970 │  143 │  411 │
# ├──────┼──────┼──────┼──────┤
# │  479 │ 1316 │ 1129 │  953 │
# ├──────┼──────┼──────┼──────┤
# │ 1389 │ 1084 │ 1747 │ 1196 │
# ├──────┼──────┼──────┼──────┤
# │  792 │ 1456 │ 3617 │  278 │
# ├──────┼──────┼──────┼──────┤
# │  306 │ 2611 │ 1080 │  601 │
# ├──────┼──────┼──────┼──────┤
# │  310 │  118 │ 2829 │ 2395 │
# ├──────┼──────┼──────┼──────┤
# │  249 │  295 │ 1027 │ 1016 │
# ├──────┼──────┼──────┼──────┤
# │  117 │  793 │  935 │ 2867 │
# ├──────┼──────┼──────┼──────┤
# │  266 │   32 │  164 │  286 │
# ├──────┼──────┼──────┼──────┤
# │   71 │ 1881 │  474 │  223 │
# ├──────┼──────┼──────┼──────┤
# ...
# Processing part number 144
# Workflow xq
# Processing part number 144
# Workflow rq
# Processing part number 144
# Workflow qm
# Processing part number 144
# Workflow nhl
# Processing part number 144
# Workflow jdc
# Part number 144 accepted
# Processing part number 145
# Workflow in
# Processing part number 145
# Workflow gx
# Processing part number 145
# Workflow jf
# Processing part number 145
# Workflow bvc
# Processing part number 145
# Workflow db
# Processing part number 145
# Workflow fqp
# Part number 145 accepted
# Processing part number 146
# Workflow in
# Processing part number 146
# Workflow gx
# Processing part number 146
# Workflow jf
# Processing part number 146
# Workflow mb
# Processing part number 146
# Workflow zzc
# Processing part number 146
# Workflow xsq
# Processing part number 146
# Workflow tmh
# Part number 146 rejected
# Processing part number 147
# Workflow in
# Processing part number 147
# Workflow gx
# Processing part number 147
# Workflow jf
# Processing part number 147
# Workflow mb
# Processing part number 147
# Workflow bps
# Processing part number 147
# Workflow jq
# Part number 147 rejected
# Processing part number 148
# Workflow in
# Processing part number 148
# Workflow gx
# Processing part number 148
# Workflow jf
# Processing part number 148
# Workflow bvc
# Processing part number 148
# Workflow gfq
# Processing part number 148
# Workflow tq
# Part number 148 accepted
# Processing part number 149
# Workflow in
# Processing part number 149
# Workflow xq
# Processing part number 149
# Workflow rq
# Processing part number 149
# Workflow bd
# Processing part number 149
# Workflow tl
# Processing part number 149
# Workflow xxd
# Processing part number 149
# Workflow cm
# Part number 149 accepted
# Processing part number 150
# Workflow in
# Processing part number 150
# Workflow gx
# Processing part number 150
# Workflow jf
# Processing part number 150
# Workflow zvv
# Processing part number 150
# Workflow nnt
# Processing part number 150
# Workflow zrl
# Processing part number 150
# Workflow pxm
# Part number 150 rejected
# Processing part number 151
# Workflow in
# Processing part number 151
# Workflow gx
# Processing part number 151
# Workflow jf
# Processing part number 151
# Workflow zvv
# Processing part number 151
# Workflow df
# Processing part number 151
# Workflow sm
# Processing part number 151
# Workflow kdf
# Part number 151 rejected
# Processing part number 152
# Workflow in
# Processing part number 152
# Workflow gx
# Processing part number 152
# Workflow jf
# Processing part number 152
# Workflow bvc
# Processing part number 152
# Workflow ths
# Processing part number 152
# Workflow bp
# Processing part number 152
# Workflow nsp
# Part number 152 accepted
# Processing part number 153
# Workflow in
# Processing part number 153
# Workflow gx
# Processing part number 153
# Workflow jf
# Processing part number 153
# Workflow zvv
# Processing part number 153
# Workflow fc
# Processing part number 153
# Workflow trl
# Processing part number 153
# Workflow hsz
# Part number 153 accepted
# Processing part number 154
# Workflow in
# Processing part number 154
# Workflow gx
# Processing part number 154
# Workflow jf
# Processing part number 154
# Workflow zvv
# Processing part number 154
# Workflow fc
# Processing part number 154
# Workflow fv
# Part number 154 rejected
# Processing part number 155
# Workflow in
# Processing part number 155
# Workflow gx
# Processing part number 155
# Workflow jf
# Processing part number 155
# Workflow zvv
# Processing part number 155
# Workflow nnt
# Processing part number 155
# Workflow jkr
# Processing part number 155
# Workflow kxc
# Part number 155 rejected
# Processing part number 156
# Workflow in
# Processing part number 156
# Workflow gx
# Processing part number 156
# Workflow jf
# Processing part number 156
# Workflow zvv
# Processing part number 156
# Workflow fc
# Processing part number 156
# Workflow fv
# Part number 156 accepted
# Processing part number 157
# Workflow in
# Processing part number 157
# Workflow xq
# Processing part number 157
# Workflow rq
# Processing part number 157
# Workflow qm
# Processing part number 157
# Workflow nhl
# Processing part number 157
# Workflow jdc
# Part number 157 accepted
# Processing part number 158
# Workflow in
# Processing part number 158
# Workflow xq
# Processing part number 158
# Workflow rq
# Processing part number 158
# Workflow qm
# Processing part number 158
# Workflow nhl
# Processing part number 158
# Workflow jdc
# Processing part number 158
# Workflow rjl
# Part number 158 accepted
# Processing part number 159
# Workflow in
# Processing part number 159
# Workflow gx
# Processing part number 159
# Workflow jf
# Processing part number 159
# Workflow zvv
# Processing part number 159
# Workflow nnt
# Processing part number 159
# Workflow jkr
# Processing part number 159
# Workflow sh
# Part number 159 rejected
# Processing part number 160
# Workflow in
# Processing part number 160
# Workflow gx
# Processing part number 160
# Workflow jf
# Processing part number 160
# Workflow mb
# Processing part number 160
# Workflow bps
# Processing part number 160
# Workflow jq
# Processing part number 160
# Workflow pmh
# Part number 160 accepted
# Processing part number 161
# Workflow in
# Processing part number 161
# Workflow gx
# Processing part number 161
# Workflow xxv
# Processing part number 161
# Workflow dnq
# Processing part number 161
# Workflow sb
# Processing part number 161
# Workflow xhk
# Processing part number 161
# Workflow gkk
# Part number 161 rejected
# Processing part number 162
# Workflow in
# Processing part number 162
# Workflow gx
# Processing part number 162
# Workflow xxv
# Processing part number 162
# Workflow vn
# Processing part number 162
# Workflow zjl
# Processing part number 162
# Workflow hxr
# Processing part number 162
# Workflow pk
# Part number 162 rejected
# Processing part number 163
# Workflow in
# Processing part number 163
# Workflow gx
# Processing part number 163
# Workflow jf
# Processing part number 163
# Workflow zvv
# Processing part number 163
# Workflow df
# Processing part number 163
# Workflow sm
# Processing part number 163
# Workflow kdf
# Part number 163 rejected
# Processing part number 164
# Workflow in
# Processing part number 164
# Workflow xq
# Processing part number 164
# Workflow rq
# Processing part number 164
# Workflow bd
# Processing part number 164
# Workflow hx
# Processing part number 164
# Workflow vl
# Part number 164 rejected
# Processing part number 165
# Workflow in
# Processing part number 165
# Workflow xq
# Processing part number 165
# Workflow rq
# Processing part number 165
# Workflow qm
# Processing part number 165
# Workflow dtt
# Processing part number 165
# Workflow xz
# Processing part number 165
# Workflow cps
# Part number 165 rejected
# Processing part number 166
# Workflow in
# Processing part number 166
# Workflow gx
# Processing part number 166
# Workflow jf
# Processing part number 166
# Workflow mb
# Processing part number 166
# Workflow bps
# Processing part number 166
# Workflow rtx
# Part number 166 rejected
# Processing part number 167
# Workflow in
# Processing part number 167
# Workflow xq
# Processing part number 167
# Workflow rq
# Processing part number 167
# Workflow bh
# Processing part number 167
# Workflow vlj
# Processing part number 167
# Workflow ml
# Processing part number 167
# Workflow dzn
# Part number 167 accepted
# Processing part number 168
# Workflow in
# Processing part number 168
# Workflow gx
# Processing part number 168
# Workflow xxv
# Processing part number 168
# Workflow vn
# Processing part number 168
# Workflow vh
# Processing part number 168
# Workflow cff
# Processing part number 168
# Workflow jxg
# Part number 168 accepted
# Processing part number 169
# Workflow in
# Processing part number 169
# Workflow gx
# Processing part number 169
# Workflow jf
# Processing part number 169
# Workflow mb
# Processing part number 169
# Workflow zzc
# Processing part number 169
# Workflow xsq
# Processing part number 169
# Workflow tmh
# Part number 169 accepted
# Processing part number 170
# Workflow in
# Processing part number 170
# Workflow gx
# Processing part number 170
# Workflow jf
# Processing part number 170
# Workflow mb
# Processing part number 170
# Workflow bps
# Processing part number 170
# Workflow jq
# Processing part number 170
# Workflow pmh
# Part number 170 accepted
# Processing part number 171
# Workflow in
# Processing part number 171
# Workflow gx
# Processing part number 171
# Workflow jf
# Processing part number 171
# Workflow mb
# Processing part number 171
# Workflow kz
# Processing part number 171
# Workflow qh
# Part number 171 accepted
# Processing part number 172
# Workflow in
# Processing part number 172
# Workflow gx
# Processing part number 172
# Workflow jf
# Processing part number 172
# Workflow mb
# Processing part number 172
# Workflow bps
# Processing part number 172
# Workflow rtx
# Processing part number 172
# Workflow lm
# Part number 172 rejected
# Processing part number 173
# Workflow in
# Processing part number 173
# Workflow gx
# Processing part number 173
# Workflow jf
# Processing part number 173
# Workflow zvv
# Processing part number 173
# Workflow fc
# Processing part number 173
# Workflow fv
# Processing part number 173
# Workflow ftv
# Part number 173 rejected
# Processing part number 174
# Workflow in
# Processing part number 174
# Workflow gx
# Processing part number 174
# Workflow jf
# Processing part number 174
# Workflow zvv
# Processing part number 174
# Workflow df
# Processing part number 174
# Workflow sm
# Processing part number 174
# Workflow kdf
# Part number 174 rejected
# Processing part number 175
# Workflow in
# Processing part number 175
# Workflow gx
# Processing part number 175
# Workflow jf
# Processing part number 175
# Workflow zvv
# Processing part number 175
# Workflow df
# Processing part number 175
# Workflow sm
# Processing part number 175
# Workflow kdf
# Part number 175 rejected
# Processing part number 176
# Workflow in
# Processing part number 176
# Workflow gx
# Processing part number 176
# Workflow xxv
# Processing part number 176
# Workflow vn
# Processing part number 176
# Workflow vh
# Processing part number 176
# Workflow kf
# Part number 176 accepted
# Processing part number 177
# Workflow in
# Processing part number 177
# Workflow gx
# Processing part number 177
# Workflow xxv
# Processing part number 177
# Workflow vn
# Processing part number 177
# Workflow gf
# Processing part number 177
# Workflow jjv
# Part number 177 accepted
# Processing part number 178
# Workflow in
# Processing part number 178
# Workflow gx
# Processing part number 178
# Workflow jf
# Processing part number 178
# Workflow mb
# Processing part number 178
# Workflow bps
# Processing part number 178
# Workflow rtx
# Processing part number 178
# Workflow lm
# Part number 178 accepted
# Processing part number 179
# Workflow in
# Processing part number 179
# Workflow gx
# Processing part number 179
# Workflow jf
# Processing part number 179
# Workflow zvv
# Processing part number 179
# Workflow nnt
# Processing part number 179
# Workflow zrl
# Processing part number 179
# Workflow pxm
# Part number 179 rejected
# Processing part number 180
# Workflow in
# Processing part number 180
# Workflow gx
# Processing part number 180
# Workflow xxv
# Processing part number 180
# Workflow dnq
# Processing part number 180
# Workflow sb
# Processing part number 180
# Workflow qdf
# Part number 180 rejected
# Processing part number 181
# Workflow in
# Processing part number 181
# Workflow gx
# Processing part number 181
# Workflow jf
# Processing part number 181
# Workflow mb
# Processing part number 181
# Workflow bps
# Processing part number 181
# Workflow rtx
# Processing part number 181
# Workflow lm
# Part number 181 accepted
# Processing part number 182
# Workflow in
# Processing part number 182
# Workflow gx
# Processing part number 182
# Workflow jf
# Processing part number 182
# Workflow zvv
# Processing part number 182
# Workflow df
# Processing part number 182
# Workflow sm
# Processing part number 182
# Workflow cc
# Part number 182 rejected
# Processing part number 183
# Workflow in
# Processing part number 183
# Workflow xq
# Processing part number 183
# Workflow rq
# Processing part number 183
# Workflow bd
# Processing part number 183
# Workflow tl
# Processing part number 183
# Workflow xxd
# Part number 183 accepted
# Processing part number 184
# Workflow in
# Processing part number 184
# Workflow gx
# Processing part number 184
# Workflow xxv
# Processing part number 184
# Workflow dnq
# Processing part number 184
# Workflow sb
# Processing part number 184
# Workflow qdf
# Part number 184 rejected
# Processing part number 185
# Workflow in
# Processing part number 185
# Workflow gx
# Processing part number 185
# Workflow jf
# Processing part number 185
# Workflow zvv
# Processing part number 185
# Workflow df
# Processing part number 185
# Workflow hfm
# Processing part number 185
# Workflow fck
# Part number 185 accepted
# Processing part number 186
# Workflow in
# Processing part number 186
# Workflow gx
# Processing part number 186
# Workflow jf
# Processing part number 186
# Workflow mb
# Processing part number 186
# Workflow bps
# Processing part number 186
# Workflow jq
# Processing part number 186
# Workflow pmh
# Part number 186 accepted
# Processing part number 187
# Workflow in
# Processing part number 187
# Workflow gx
# Processing part number 187
# Workflow jf
# Processing part number 187
# Workflow mb
# Processing part number 187
# Workflow bps
# Processing part number 187
# Workflow rtx
# Processing part number 187
# Workflow qhd
# Part number 187 rejected
# Processing part number 188
# Workflow in
# Processing part number 188
# Workflow gx
# Processing part number 188
# Workflow xxv
# Processing part number 188
# Workflow dnq
# Processing part number 188
# Workflow ffc
# Processing part number 188
# Workflow mmg
# Part number 188 accepted
# Processing part number 189
# Workflow in
# Processing part number 189
# Workflow gx
# Processing part number 189
# Workflow jf
# Processing part number 189
# Workflow zvv
# Processing part number 189
# Workflow fc
# Processing part number 189
# Workflow fv
# Processing part number 189
# Workflow ftv
# Part number 189 accepted
# Processing part number 190
# Workflow in
# Processing part number 190
# Workflow gx
# Processing part number 190
# Workflow xxv
# Processing part number 190
# Workflow vn
# Processing part number 190
# Workflow vh
# Processing part number 190
# Workflow kf
# Processing part number 190
# Workflow nm
# Part number 190 accepted
# Processing part number 191
# Workflow in
# Processing part number 191
# Workflow gx
# Processing part number 191
# Workflow jf
# Processing part number 191
# Workflow mb
# Processing part number 191
# Workflow bps
# Processing part number 191
# Workflow jq
# Part number 191 rejected
# Processing part number 192
# Workflow in
# Processing part number 192
# Workflow xq
# Processing part number 192
# Workflow rq
# Processing part number 192
# Workflow qm
# Processing part number 192
# Workflow nhl
# Processing part number 192
# Workflow jdc
# Processing part number 192
# Workflow rjl
# Part number 192 accepted
# Processing part number 193
# Workflow in
# Processing part number 193
# Workflow gx
# Processing part number 193
# Workflow jf
# Processing part number 193
# Workflow mb
# Processing part number 193
# Workflow zzc
# Processing part number 193
# Workflow xsq
# Processing part number 193
# Workflow tmh
# Part number 193 accepted
# Processing part number 194
# Workflow in
# Processing part number 194
# Workflow gx
# Processing part number 194
# Workflow xxv
# Processing part number 194
# Workflow vn
# Processing part number 194
# Workflow jn
# Processing part number 194
# Workflow knb
# Part number 194 accepted
# Processing part number 195
# Workflow in
# Processing part number 195
# Workflow gx
# Processing part number 195
# Workflow jf
# Processing part number 195
# Workflow zvv
# Processing part number 195
# Workflow df
# Processing part number 195
# Workflow sm
# Processing part number 195
# Workflow kdf
# Part number 195 rejected
# Processing part number 196
# Workflow in
# Processing part number 196
# Workflow gx
# Processing part number 196
# Workflow xxv
# Processing part number 196
# Workflow vn
# Processing part number 196
# Workflow jn
# Processing part number 196
# Workflow hn
# Part number 196 accepted
# Processing part number 197
# Workflow in
# Processing part number 197
# Workflow xq
# Processing part number 197
# Workflow rq
# Processing part number 197
# Workflow qm
# Processing part number 197
# Workflow dq
# Processing part number 197
# Workflow rj
# Processing part number 197
# Workflow ggm
# Part number 197 accepted
# Processing part number 198
# Workflow in
# Processing part number 198
# Workflow gx
# Processing part number 198
# Workflow jf
# Processing part number 198
# Workflow zvv
# Processing part number 198
# Workflow fc
# Processing part number 198
# Workflow fv
# Part number 198 rejected
# Processing part number 199
# Workflow in
# Processing part number 199
# Workflow gx
# Processing part number 199
# Workflow jf
# Processing part number 199
# Workflow mb
# Processing part number 199
# Workflow bps
# Processing part number 199
# Workflow rtx
# Processing part number 199
# Workflow lm
# Part number 199 accepted
# 487623

# %%
from tabulate import TableFormat, tabulate
from math import prod
from copy import deepcopy

f = open("input.txt", "r")

workflows = {}

for line in f:
    if line =='\n':
        break
    line = line.replace('\n', '')
    [name, workflow] = line.split('{')
    workflow = workflow.replace('}', '')
    rules = workflow.split(',')
    workflow = []
    for rule in rules:
        if ':' in rule:
            [condition, destination] = rule.split(':')
            if '<' in condition:
                [rating, threshold] = condition.split('<')
                operator = '<'
            elif '>' in condition:
                [rating, threshold] = condition.split('>')
                operator = '>'
            else:
                raise ValueError
            threshold = int(threshold)
            workflow.append({"operator": operator, "rating": rating, "threshold": threshold, "destination": destination})
        else:
            destination = rule
            workflow.append({"destination": destination})
    workflows[name] = workflow

print(tabulate(workflows, headers="keys", tablefmt="rounded_grid"))

possibilities = {}

for workflow_name in workflows:
    workflow = workflows[workflow_name]
    # possibilities[workflow_name] will contain the possible ranges for ratings for each destination
    # reachable through workflow workflow_name 
    possibilities[workflow_name] = {}
    # Default ranges, without constraints
    rating_ranges= {"x": [1, 4000], "m": [1, 4000], "a": [1, 4000], "s": [1, 4000]}
    for rule in workflow:
        destination = rule["destination"]
        # For some workflows, destinations are reachable in multiple ways
        if destination not in possibilities[workflow_name]:
            possibilities[workflow_name][destination] = []
        rating_ranges_copy = deepcopy(rating_ranges)
        if "rating" not in rule:
            # A rule without condition, the ranges remain as they are
            possibilities[workflow_name][destination].append(rating_ranges_copy)
        else:
            # A rule with a condition
            rating = rule["rating"]
            operator = rule["operator"]
            threshold = rule["threshold"]
            # The ranges for the rating are adapted accordingly
            match operator:
                case '<':
                    rating_ranges_copy[rating][1] = threshold-1
                    rating_ranges[rating][0] = threshold
                case '>':
                    rating_ranges_copy[rating][0] = threshold+1
                    rating_ranges[rating][1] = threshold
                case _:
                    raise
            # We add the current ranges to the possibilities for this destination from this workflow
            possibilities[workflow_name][destination].append(rating_ranges_copy)

def possibilitesForAcceptance(possibilities, workflow_name, current_rating_ranges_list):
    total = 0
    # We go through all destinations that are susceptible to lead us to an "A" eventually 
    for destination, rating_ranges_list in possibilities[workflow_name].items():
        new_rating_ranges_list = []
        # For each destination we have a list of possiblities of ranges
        for rating_ranges in rating_ranges_list:
            # We called this function with a list of possibilities of ranges already set 
            # (from previous workflows that lead to this one)
            for current_rating_ranges in current_rating_ranges_list:
                new_rating_ranges = {}
                to_add = True
                for key in rating_ranges:
                    # For each rating, we merge the ranges we have
                    [current_min, current_max] = current_rating_ranges[key]
                    [workflow_min, workflow_max] = rating_ranges[key]
                    new_rating_ranges[key] = [max(current_min, workflow_min), min(current_max, workflow_max)]
                    if new_rating_ranges[key][1] < new_rating_ranges[key][0]:
                        # If the resulting range isn't valid, there's no need to go on, this set of ranges 
                        # can be thrown away
                        to_add = False
                        break
                if to_add:
                    # If we only had valid ranges, we add this set to the possibilities
                    new_rating_ranges_list.append(new_rating_ranges)
        if destination == 'A':
            # We've reached acceptance, now we need to compute the number of possible combinations of ratings
            # that could have lead here
            total_nb_of_poss = 0
            # Simply multiply the width of all the ranges for all the lists for destination 'A' 
            # and add them up together
            for rating_ranges in new_rating_ranges_list:
                nb_of_poss = 1
                for key in rating_ranges:
                    nb_of_poss *= (rating_ranges[key][1] - rating_ranges[key][0] + 1)
                total_nb_of_poss += nb_of_poss
            total += total_nb_of_poss
        elif destination == 'R':
            # We've reached rejection, no way to reach acceptance after this so we move on
            continue
        else:
            # This leads to another workflow, with an updated ranges list
            total += possibilitesForAcceptance(possibilities, destination, new_rating_ranges_list)
    return total

initial_rating_ranges= [{"x": [1, 4000], "m": [1, 4000], "a": [1, 4000], "s": [1, 4000]}]
# The first workflow is "in", with the initial constraints on the ratings
print(possibilitesForAcceptance(possibilities, "in", initial_rating_ranges))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────── ...
# │ mn                                                                      │ jcj                                                                     │ lm                                                                      │ hfm                                                                     │ gvr                                                                       │ xd                                                                      │ gms                                                                       │ nsv                                                                     │ gz                                                                      │ lc                                                                      │ qc                                                                      │ ndl                                                                      │ vfz                                                                       │ ld                                                                        │ jlj                                                                     │ nn                                                                       │ kfq                                                                     │ xl                                                                        │ tz                                                                        │ gf                                                                        │ zf                                                                       │ rkm                                                                       │ sh                                                                      │ zm                                                                      │ fd                                                                      │ qr                                                                      │ tvj                                                                       │ frn                                                                       │ sf                                                                      │ tx                                                                        │ mrf                                                                     │ jkr                                                                       │ sc                                                                      │ tzc                                                                     │ cml                                                                     │ rp                                                                      │ cmn                                                                     │ dsf                                                                    │ zvv                                                                      │ sb                                                                        │ xk                                                                     │ jf                                                                        │ ktt                                                                    │ lvj                                                                       │ fsj                                                                     │ vn                                                                        │ nv                                                                      │ rf                                                                       │ rh                                                                      │ dq                                                                       │ qpl                                                                      │ mz                                                                        │ ggm                                                                     │ vf                                     ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '<', 'rating': 's', 'threshold': 3661, 'destination': 'A'} │ {'operator': '<', 'rating': 'x', 'threshold': 2501, 'destination': 'R'} │ {'operator': '>', 'rating': 's', 'threshold': 1017, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 661, 'destination': 'gm'} │ {'operator': '<', 'rating': 'x', 'threshold': 1627, 'destination': 'jlj'} │ {'operator': '<', 'rating': 'a', 'threshold': 3515, 'destination': 'A'} │ {'operator': '<', 'rating': 'a', 'threshold': 3153, 'destination': 'tbr'} │ {'operator': '<', 'rating': 'a', 'threshold': 1742, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 1839, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 2328, 'destination': 'A'} │ {'operator': '<', 'rating': 'x', 'threshold': 1673, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3705, 'destination': 'tr'} │ {'operator': '<', 'rating': 'a', 'threshold': 3535, 'destination': 'tpv'} │ {'operator': '<', 'rating': 'x', 'threshold': 2662, 'destination': 'kdb'} │ {'operator': '>', 'rating': 'a', 'threshold': 2672, 'destination': 'A'} │ {'operator': '<', 'rating': 'a', 'threshold': 2837, 'destination': 'mm'} │ {'operator': '>', 'rating': 'm', 'threshold': 3404, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 1669, 'destination': 'A'}   │ {'operator': '>', 'rating': 'x', 'threshold': 2729, 'destination': 'A'}   │ {'operator': '<', 'rating': 'a', 'threshold': 1839, 'destination': 'jjv'} │ {'operator': '<', 'rating': 'x', 'threshold': 2559, 'destination': 'R'}  │ {'operator': '<', 'rating': 'x', 'threshold': 2920, 'destination': 'qpl'} │ {'operator': '<', 'rating': 's', 'threshold': 950, 'destination': 'R'}  │ {'operator': '<', 'rating': 'a', 'threshold': 3311, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 1125, 'destination': 'A'} │ {'operator': '>', 'rating': 'a', 'threshold': 1507, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'threshold': 1336, 'destination': 'gqp'} │ {'operator': '<', 'rating': 'x', 'threshold': 3485, 'destination': 'vfx'} │ {'operator': '<', 'rating': 'x', 'threshold': 2428, 'destination': 'R'} │ {'operator': '<', 'rating': 'a', 'threshold': 835, 'destination': 'R'}    │ {'operator': '>', 'rating': 'x', 'threshold': 1667, 'destination': 'A'} │ {'operator': '<', 'rating': 'm', 'threshold': 2927, 'destination': 'kxc'} │ {'operator': '>', 'rating': 's', 'threshold': 1038, 'destination': 'A'} │ {'operator': '>', 'rating': 'm', 'threshold': 2622, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 2768, 'destination': 'R'} │ {'operator': '<', 'rating': 'a', 'threshold': 3056, 'destination': 'R'} │ {'operator': '<', 'rating': 'm', 'threshold': 1877, 'destination': 'A'} │ {'operator': '>', 'rating': 'm', 'threshold': 720, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 1686, 'destination': 'df'} │ {'operator': '<', 'rating': 'a', 'threshold': 157, 'destination': 'xhk'}  │ {'operator': '>', 'rating': 'a', 'threshold': 390, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 441, 'destination': 'zvv'}  │ {'operator': '>', 'rating': 'a', 'threshold': 231, 'destination': 'R'} │ {'operator': '>', 'rating': 'x', 'threshold': 3711, 'destination': 'zpn'} │ {'operator': '>', 'rating': 'x', 'threshold': 3517, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 1525, 'destination': 'jn'}  │ {'operator': '>', 'rating': 's', 'threshold': 3581, 'destination': 'R'} │ {'operator': '>', 'rating': 'm', 'threshold': 2639, 'destination': 'A'}  │ {'operator': '>', 'rating': 'a', 'threshold': 813, 'destination': 'R'}  │ {'operator': '<', 'rating': 'x', 'threshold': 2671, 'destination': 'rj'} │ {'operator': '<', 'rating': 's', 'threshold': 3540, 'destination': 'mv'} │ {'operator': '<', 'rating': 'a', 'threshold': 2856, 'destination': 'R'}   │ {'operator': '<', 'rating': 's', 'threshold': 2962, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '>', 'rating': 's', 'threshold': 3705, 'destination': 'A'} │ {'operator': '<', 'rating': 's', 'threshold': 516, 'destination': 'R'}  │ {'operator': '>', 'rating': 'a', 'threshold': 470, 'destination': 'R'}  │ {'destination': 'fck'}                                                  │ {'destination': 'R'}                                                      │ {'operator': '<', 'rating': 'x', 'threshold': 1086, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 1274, 'destination': 'hgz'} │ {'operator': '>', 'rating': 'x', 'threshold': 142, 'destination': 'R'}  │ {'operator': '>', 'rating': 'x', 'threshold': 1848, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'threshold': 3513, 'destination': 'A'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'a', 'threshold': 3474, 'destination': 'zr'} │ {'destination': 'R'}                                                      │ {'operator': '>', 'rating': 'x', 'threshold': 2851, 'destination': 'A'}   │ {'destination': 'R'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 3088, 'destination': 'zj'} │ {'operator': '>', 'rating': 'm', 'threshold': 3071, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3278, 'destination': 'kdg'} │ {'operator': '>', 'rating': 'a', 'threshold': 1540, 'destination': 'A'}   │ {'operator': '>', 'rating': 's', 'threshold': 3144, 'destination': 'tfn'} │ {'operator': '<', 'rating': 'a', 'threshold': 3507, 'destination': 'bg'} │ {'destination': 'hq'}                                                     │ {'operator': '<', 'rating': 's', 'threshold': 1280, 'destination': 'R'} │ {'operator': '<', 'rating': 's', 'threshold': 3539, 'destination': 'R'} │ {'operator': '>', 'rating': 'm', 'threshold': 1688, 'destination': 'R'} │ {'operator': '<', 'rating': 'x', 'threshold': 236, 'destination': 'R'}  │ {'destination': 'tv'}                                                     │ {'destination': 'vgj'}                                                    │ {'operator': '>', 'rating': 's', 'threshold': 1024, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3130, 'destination': 'skj'} │ {'operator': '<', 'rating': 'a', 'threshold': 3699, 'destination': 'R'} │ {'operator': '>', 'rating': 'a', 'threshold': 2049, 'destination': 'R'}   │ {'destination': 'R'}                                                    │ {'operator': '<', 'rating': 's', 'threshold': 1490, 'destination': 'R'} │ {'destination': 'R'}                                                    │ {'destination': 'A'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 103, 'destination': 'A'}  │ {'destination': 'A'}                                                   │ {'operator': '<', 'rating': 'a', 'threshold': 1613, 'destination': 'fc'} │ {'operator': '<', 'rating': 'x', 'threshold': 1408, 'destination': 'qdf'} │ {'operator': '<', 'rating': 'x', 'threshold': 198, 'destination': 'R'} │ {'operator': '>', 'rating': 'a', 'threshold': 2404, 'destination': 'jqg'} │ {'destination': 'R'}                                                   │ {'operator': '<', 'rating': 'x', 'threshold': 3392, 'destination': 'tlf'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'x', 'threshold': 1345, 'destination': 'zjl'} │ {'operator': '<', 'rating': 's', 'threshold': 3340, 'destination': 'A'} │ {'operator': '>', 'rating': 's', 'threshold': 3257, 'destination': 'zm'} │ {'operator': '>', 'rating': 's', 'threshold': 3042, 'destination': 'A'} │ {'destination': 'qz'}                                                    │ {'destination': 'A'}                                                     │ {'operator': '>', 'rating': 'a', 'threshold': 3430, 'destination': 'pvc'} │ {'operator': '>', 'rating': 'x', 'threshold': 2214, 'destination': 'A'} │ {'operator': '>', 'rating': 'x', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'operator': '<', 'rating': 'm', 'threshold': 1698, 'destination': 'R'} │ {'destination': 'A'}                                                    │ {'operator': '>', 'rating': 'x', 'threshold': 159, 'destination': 'A'}  │                                                                         │                                                                           │ {'destination': 'R'}                                                    │ {'destination': 'mkg'}                                                    │ {'destination': 'dvh'}                                                  │ {'destination': 'R'}                                                    │ {'destination': 'R'}                                                    │                                                                         │ {'operator': '<', 'rating': 'x', 'threshold': 1760, 'destination': 'pl'} │                                                                           │ {'operator': '<', 'rating': 'm', 'threshold': 3657, 'destination': 'gt'}  │                                                                         │ {'operator': '>', 'rating': 'm', 'threshold': 1332, 'destination': 'zf'} │ {'destination': 'nh'}                                                   │ {'destination': 'pm'}                                                     │ {'operator': '<', 'rating': 'x', 'threshold': 2269, 'destination': 'ttv'} │ {'operator': '<', 'rating': 'x', 'threshold': 1424, 'destination': 'gpj'} │ {'operator': '>', 'rating': 'a', 'threshold': 3813, 'destination': 'A'}  │                                                                           │ {'operator': '>', 'rating': 'a', 'threshold': 1876, 'destination': 'A'} │ {'destination': 'R'}                                                    │ {'destination': 'A'}                                                    │ {'destination': 'R'}                                                    │                                                                           │                                                                           │ {'operator': '<', 'rating': 's', 'threshold': 385, 'destination': 'R'}  │ {'destination': 'ct'}                                                     │ {'destination': 'R'}                                                    │ {'destination': 'sh'}                                                     │                                                                         │ {'destination': 'A'}                                                    │                                                                         │                                                                         │ {'destination': 'mxg'}                                                  │                                                                        │ {'destination': 'nnt'}                                                   │ {'operator': '<', 'rating': 'm', 'threshold': 1174, 'destination': 'ff'}  │ {'operator': '>', 'rating': 'a', 'threshold': 189, 'destination': 'A'} │ {'operator': '>', 'rating': 'a', 'threshold': 1410, 'destination': 'bvc'} │                                                                        │ {'destination': 'R'}                                                      │                                                                         │ {'operator': '<', 'rating': 's', 'threshold': 1431, 'destination': 'vh'}  │ {'destination': 'A'}                                                    │ {'destination': 'jg'}                                                    │ {'operator': '>', 'rating': 's', 'threshold': 2781, 'destination': 'A'} │                                                                          │                                                                          │ {'operator': '<', 'rating': 'x', 'threshold': 2330, 'destination': 'ftt'} │ {'destination': 'A'}                                                    │ {'operator': '<', 'rating': 'a', 'thre ...
# ├─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────── ...
# │ {'destination': 'A'}                                                    │                                                                         │ {'destination': 'R'}                                                    │                                                                         │                                                                           │                                                                         │                                                                           │                                                                         │                                                                         │                                                                         │                                                                         │ {'destination': 'R'}                                                     │                                                                           │ {'destination': 'A'}                                                      │                                                                         │ {'destination': 'tn'}                                                    │                                                                         │                                                                           │ {'destination': 'tkd'}                                                    │ {'destination': 'ztz'}                                                    │ {'destination': 'xsf'}                                                   │                                                                           │ {'destination': 'A'}                                                    │                                                                         │                                                                         │                                                                         │                                                                           │                                                                           │ {'destination': 'R'}                                                    │                                                                           │                                                                         │                                                                           │                                                                         │                                                                         │                                                                         │                                                                         │                                                                         │                                                                        │                                                                          │ {'destination': 'zp'}                                                     │ {'destination': 'A'}                                                   │ {'destination': 'mb'}                                                     │                                                                        │                                                                           │                                                                         │ {'destination': 'gf'}                                                     │                                                                         │                                                                          │ {'destination': 'R'}                                                    │                                                                          │                                                                          │ {'destination': 'pg'}                                                     │                                                                         │ {'destination': 'A'}                   ...
# ╰─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────── ...
# 113550238315130
