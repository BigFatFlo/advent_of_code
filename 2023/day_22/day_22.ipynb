# %%
from collections import defaultdict
from copy import deepcopy

f = open("input.txt", "r")

class Brick:
    def __init__(self, start, end) -> None:
        self.start = start
        self.end = end
        self.final_z_start = self.start[2]
        self.final_z_end = self.end[2]
        self.supporting_bricks = set()
        self.supported_bricks = set()

    def supportBrick(self, brick):
        self.supported_bricks.add(brick)

    def isSupportedBy(self, brick):
        self.supporting_bricks.add(brick)

    def removeSupportFrom(self, brick):
        if brick in self.supporting_bricks:
            self.supporting_bricks.remove(brick)

bricks_for_z = defaultdict(list)
z_with_bricks = set()
bricks = []

for line in f:
    [start_coords, end_coords] = line.replace('\n','').split('~')
    start_coords = [int(n) for n in start_coords.split(',')]
    end_coords = [int(n) for n in end_coords.split(',')]
    new_brick = Brick(start_coords, end_coords)
    starting_z = start_coords[2]
    bricks_for_z[starting_z].append(new_brick)
    bricks.append(new_brick)
    z_with_bricks.add(starting_z)

z_with_bricks = sorted(list(z_with_bricks))
height = z_with_bricks[-1]

grid_for_z = [{} for z in range(height+1)]

# For a give height, show all the coordinates where bricks are present
def printGridForZ(z):
    print(f"Grid for z {z}")
    for (x, y), brick in grid_for_z[z].items():
        print(f"({x}, {y}): {brick.start}~{brick.end}")

for z in z_with_bricks:
    # We process bricks by order of starting height
    while len(bricks_for_z[z]) > 0:
        # Process one brick at a time
        brick = bricks_for_z[z].pop()
        start = brick.start
        end = brick.end
        z_to_check = start[2]-1
        # Figure out the first height at which there is a potential obstacle
        while z_to_check > len(grid_for_z):
            z_to_check-=1
        # If we've reached the ground, there's no way to go down further
        can_go_down = (z_to_check >= 1)
        while can_go_down and z_to_check >= 1:
            if z_to_check < len(grid_for_z):
                # The grid represents the coordinates where a brick is present
                grid = grid_for_z[z_to_check]   
                x = start[0]
                while x <= end[0]:
                    y = start[1]
                    while y <= end[1]:
                        # For each block of the current brick, we check if its coordinates
                        # are already taken by another brick at this height
                        if (x,y) in grid:
                            # If they are, the brick stops here and we register the supporter/supported relation
                            can_go_down = False
                            grid[(x,y)].supportBrick(brick)
                            brick.isSupportedBy(grid[(x,y)])
                        y+=1
                    x+=1
            # We keep going down if the brick hasn't encountered an obstacle (other brick or ground)
            if can_go_down:
                z_to_check -= 1
        z_to_fill = z_to_check+1
        # We've found the final resting height of the brick, now we need to update the grid
        # for each height occupied by the brick
        for zz in range(z_to_fill, z_to_fill + end[2]-start[2]+1):
            for x in range(start[0], end[0]+1):
                for y in range(start[1], end[1]+1):
                    grid_for_z[zz][(x, y)] = brick
        # Finally we register the final resting place of the brick
        brick.final_z_start = z_to_fill
        brick.final_z_end = z_to_fill + end[2]-start[2]

# for z in range(len(grid_for_z)):
#     printGridForZ(z)

total_nb_of_bricks_that_can_be_disintegrated = 0

for brick in bricks:
    supported_bricks = [f"{b.start}~{b.end}" for b in brick.supported_bricks]
    supporting_bricks = [f"{b.start}~{b.end}" for b in brick.supporting_bricks]
    can_be_disintegrated = True
    for b in brick.supported_bricks:
        if len(b.supporting_bricks) == 1:
            # If one supported bricks has no other supporting bricks, it will fall
            can_be_disintegrated = False
            break
    if can_be_disintegrated:
        total_nb_of_bricks_that_can_be_disintegrated += 1

print(total_nb_of_bricks_that_can_be_disintegrated)

def disintegrateBrick(brick):
    for b in brick.supported_bricks:
        b.removeSupportFrom(brick)
        if len(b.supporting_bricks) == 0:
            # The brick b has no support any more, it's going to fall
            # So we need to simulate its fall next
            disintegrateBrick(b)

def countUnsupportedBricks(bricks):
    total = 0
    for brick in bricks:
        # If the brick is resting on the ground, it's supported
        if brick.final_z_start > 1 and len(brick.supporting_bricks) == 0:
            total += 1
    return total

def printStack(bricks):
    # Print all bricks in order
    for brick in bricks:
        supported_bricks = [f"{b.start}~{b.end}" for b in brick.supported_bricks]
        supporting_bricks = [f"{b.start}~{b.end}" for b in brick.supporting_bricks]
        print(f"{brick.start}~{brick.end} resting at z={brick.final_z_start},{brick.final_z_end} supporting {supported_bricks} and supported by {supporting_bricks}")

total = 0
brick_index = 0
while brick_index < len(bricks):
    # We're going to simulate the chain reaction for each brick, so we need to work on a copy
    bricks_copy = deepcopy(bricks)
    brick = bricks_copy[brick_index]
    supported_bricks = [f"{b.start}~{b.end}" for b in brick.supported_bricks]
    supporting_bricks = [f"{b.start}~{b.end}" for b in brick.supporting_bricks]
    print(f"Brick {brick_index} out of {len(bricks)}")
    print(f"Disintegrating {brick.start}~{brick.end} resting at z={brick.final_z_start},{brick.final_z_end} supporting {supported_bricks} and supported by {supporting_bricks}")
    disintegrateBrick(brick)
    falling_bricks = countUnsupportedBricks(bricks_copy)
    print(falling_bricks)
    total += falling_bricks
    brick_index+=1

print(total)
# Out:
# 465
# Brick 0 out of 1394
# Disintegrating [5, 5, 156]~[5, 7, 156] resting at z=83,83 supporting ['[3, 6, 158]~[5, 6, 158]'] and supported by ['[5, 7, 154]~[7, 7, 154]']
# 521
# Brick 1 out of 1394
# Disintegrating [8, 5, 82]~[8, 7, 82] resting at z=41,41 supporting ['[8, 5, 83]~[9, 5, 83]'] and supported by ['[8, 4, 81]~[8, 6, 81]']
# 1
# Brick 2 out of 1394
# Disintegrating [6, 5, 196]~[6, 7, 196] resting at z=99,99 supporting ['[5, 6, 198]~[7, 6, 198]', '[6, 7, 198]~[6, 9, 198]', '[3, 5, 202]~[6, 5, 202]'] and supported by ['[5, 7, 193]~[9, 7, 193]']
# 4
# Brick 3 out of 1394
# Disintegrating [0, 7, 7]~[0, 8, 7] resting at z=3,3 supporting ['[0, 7, 8]~[0, 7, 10]'] and supported by ['[0, 8, 4]~[0, 9, 4]']
# 1
# Brick 4 out of 1394
# Disintegrating [2, 3, 129]~[2, 6, 129] resting at z=63,63 supporting ['[0, 6, 130]~[2, 6, 130]'] and supported by ['[1, 6, 125]~[3, 6, 125]', '[2, 4, 126]~[4, 4, 126]']
# 1
# Brick 5 out of 1394
# Disintegrating [9, 5, 265]~[9, 7, 265] resting at z=127,127 supporting ['[9, 4, 268]~[9, 6, 268]'] and supported by ['[7, 7, 262]~[9, 7, 262]']
# 6
# Brick 6 out of 1394
# Disintegrating [1, 4, 278]~[3, 4, 278] resting at z=137,137 supporting ['[2, 3, 281]~[2, 6, 281]', '[1, 2, 280]~[1, 5, 280]', '[3, 4, 279]~[3, 6, 279]'] and supported by ['[1, 4, 277]~[3, 4, 277]']
# 8
# Brick 7 out of 1394
# Disintegrating [2, 6, 149]~[4, 6, 149] resting at z=74,74 supporting [] and supported by ['[3, 6, 148]~[3, 8, 148]']
# 0
# Brick 8 out of 1394
# Disintegrating [7, 7, 246]~[9, 7, 246] resting at z=118,118 supporting ['[5, 7, 248]~[8, 7, 248]'] and supported by ['[7, 4, 245]~[7, 7, 245]']
# 14
# Brick 9 out of 1394
# Disintegrating [8, 6, 282]~[9, 6, 282] resting at z=140,140 supporting [] and supported by ['[8, 5, 281]~[8, 7, 281]']
# 0
# Brick 10 out of 1394
# Disintegrating [1, 1, 289]~[1, 5, 289] resting at z=143,143 supporting ['[1, 0, 291]~[1, 2, 291]', '[1, 4, 292]~[1, 6, 292]'] and supported by ['[1, 3, 288]~[4, 3, 288]']
# 22
# Brick 11 out of 1394
# Disintegrating [7, 3, 70]~[7, 6, 70] resting at z=34,34 supporting ['[4, 6, 71]~[7, 6, 71]', '[7, 1, 71]~[7, 4, 71]'] and supported by ['[7, 5, 64]~[7, 5, 67]']
# 1047
# Brick 12 out of 1394
# Disintegrating [3, 9, 278]~[3, 9, 280] resting at z=136,138 supporting ['[3, 8, 282]~[3, 9, 282]'] and supported by ['[3, 9, 275]~[4, 9, 275]']
# 10
# Brick 13 out of 1394
# Disintegrating [6, 9, 261]~[7, 9, 261] resting at z=124,124 supporting [] and supported by ['[7, 8, 258]~[7, 9, 258]']
# 0
# Brick 14 out of 1394
# Disintegrating [3, 5, 75]~[5, 5, 75] resting at z=38,38 supporting ['[5, 5, 78]~[8, 5, 78]', '[1, 5, 78]~[3, 5, 78]', '[4, 5, 76]~[4, 7, 76]'] and supported by ['[5, 2, 74]~[5, 5, 74]']
# 991
# Brick 15 out of 1394
# Disintegrating [3, 1, 221]~[3, 1, 224] resting at z=110,113 supporting ['[1, 1, 232]~[4, 1, 232]'] and supported by ['[1, 1, 219]~[3, 1, 219]']
# 18
# Brick 16 out of 1394
# Disintegrating [0, 9, 211]~[2, 9, 211] resting at z=105,105 supporting ['[1, 9, 213]~[1, 9, 215]'] and supported by ['[0, 9, 210]~[3, 9, 210]']
# 10
# Brick 17 out of 1394
# Disintegrating [3, 9, 251]~[4, 9, 251] resting at z=121,121 supporting [] and supported by ['[4, 7, 249]~[4, 9, 249]']
# 0
# Brick 18 out of 1394
# Disintegrating [0, 4, 28]~[2, 4, 28] resting at z=14,14 supporting ['[2, 3, 30]~[2, 5, 30]'] and supported by ['[1, 2, 27]~[1, 4, 27]', '[2, 2, 27]~[2, 4, 27]']
# 0
# Brick 19 out of 1394
# Disintegrating [2, 7, 291]~[2, 7, 293] resting at z=143,145 supporting ['[0, 7, 295]~[2, 7, 295]'] and supported by ['[2, 4, 289]~[2, 7, 289]']
# 12
# Brick 20 out of 1394
# Disintegrating [4, 3, 2]~[4, 5, 2] resting at z=1,1 supporting [] and supported by []
# 0
# Brick 21 out of 1394
# Disintegrating [5, 4, 96]~[5, 5, 96] resting at z=48,48 supporting [] and supported by ['[5, 5, 94]~[5, 8, 94]']
# 0
# Brick 22 out of 1394
# Disintegrating [5, 4, 60]~[5, 7, 60] resting at z=28,28 supporting ['[5, 4, 62]~[5, 6, 62]'] and supported by ['[5, 4, 57]~[6, 4, 57]']
# 7
# Brick 23 out of 1394
# Disintegrating [1, 2, 45]~[4, 2, 45] resting at z=21,21 supporting ['[4, 2, 47]~[4, 2, 47]', '[0, 2, 46]~[1, 2, 46]'] and supported by ['[4, 0, 43]~[4, 2, 43]']
# 9
# Brick 24 out of 1394
# Disintegrating [3, 6, 145]~[3, 9, 145] resting at z=70,70 supporting ['[0, 6, 146]~[3, 6, 146]'] and supported by ['[3, 9, 142]~[5, 9, 142]', '[2, 7, 136]~[5, 7, 136]']
# 0
# Brick 25 out of 1394
# Disintegrating [9, 1, 214]~[9, 4, 214] resting at z=108,108 supporting ['[9, 4, 216]~[9, 5, 216]', '[9, 0, 216]~[9, 2, 216]'] and supported by ['[6, 2, 212]~[9, 2, 212]']
# 1
# Brick 26 out of 1394
# Disintegrating [0, 4, 121]~[0, 6, 121] resting at z=59,59 supporting ['[0, 0, 122]~[0, 4, 122]'] and supported by ['[0, 4, 118]~[0, 7, 118]']
# 36
# Brick 27 out of 1394
# Disintegrating [6, 5, 22]~[8, 5, 22] resting at z=11,11 supporting ['[6, 5, 24]~[6, 7, 24]'] and supported by ['[7, 5, 20]~[7, 7, 20]']
# 0
# Brick 28 out of 1394
# Disintegrating [2, 8, 211]~[4, 8, 211] resting at z=105,105 supporting ['[4, 8, 214]~[7, 8, 214]'] and supported by ['[1, 8, 210]~[3, 8, 210]', '[4, 6, 207]~[4, 9, 207]']
# 7
# Brick 29 out of 1394
# Disintegrating [5, 0, 215]~[6, 0, 215] resting at z=108,108 supporting ['[6, 0, 217]~[6, 0, 219]'] and supported by ['[4, 0, 214]~[7, 0, 214]']
# 1
# Brick 30 out of 1394
# Disintegrating [7, 1, 80]~[7, 4, 80] resting at z=40,40 supporting ['[7, 0, 81]~[7, 2, 81]', '[7, 3, 83]~[7, 4, 83]'] and supported by ['[4, 4, 79]~[7, 4, 79]', '[7, 1, 79]~[9, 1, 79]', '[6, 3, 78]~[9, 3, 78]']
# 2
# Brick 31 out of 1394
# Disintegrating [4, 9, 2]~[6, 9, 2] resting at z=1,1 supporting ['[4, 9, 4]~[4, 9, 6]', '[5, 9, 5]~[5, 9, 6]'] and supported by []
# 5
# Brick 32 out of 1394
# Disintegrating [5, 8, 13]~[7, 8, 13] resting at z=8,8 supporting ['[3, 8, 16]~[5, 8, 16]', '[6, 8, 14]~[8, 8, 14]'] and supported by ['[3, 8, 10]~[5, 8, 10]']
# 3
# Brick 33 out of 1394
# Disintegrating [0, 9, 210]~[3, 9, 210] resting at z=104,104 supporting ['[0, 9, 211]~[2, 9, 211]'] and supported by ['[2, 7, 208]~[2, 9, 208]', '[1, 6, 207]~[1, 9, 207]']
# 11
# Brick 34 out of 1394
# Disintegrating [6, 6, 107]~[6, 8, 107] resting at z=52,52 supporting ['[6, 7, 110]~[7, 7, 110]', '[6, 4, 108]~[6, 6, 108]'] and supported by ['[6, 7, 102]~[6, 9, 102]', '[4, 6, 104]~[7, 6, 104]']
# 181
# Brick 35 out of 1394
# Disintegrating [6, 7, 228]~[6, 9, 228] resting at z=113,113 supporting ['[5, 8, 231]~[6, 8, 231]'] and supported by ['[4, 9, 226]~[6, 9, 226]']
# 1
# Brick 36 out of 1394
# Disintegrating [0, 9, 96]~[2, 9, 96] resting at z=49,49 supporting [] and supported by ['[1, 9, 93]~[5, 9, 93]']
# 0
# Brick 37 out of 1394
# Disintegrating [0, 0, 101]~[0, 0, 102] resting at z=50,51 supporting [] and supported by ['[0, 0, 100]~[2, 0, 100]']
# 0
# Brick 38 out of 1394
# Disintegrating [6, 4, 108]~[6, 6, 108] resting at z=53,53 supporting ['[3, 6, 111]~[6, 6, 111]', '[6, 5, 110]~[6, 5, 112]', '[6, 4, 111]~[6, 4, 113]'] and supported by ['[6, 6, 107]~[6, 8, 107]']
# 169
# Brick 39 out of 1394
# Disintegrating [5, 2, 237]~[5, 2, 240] resting at z=115,118 supporting [] and supported by ['[5, 1, 234]~[5, 3, 234]']
# 0
# Brick 40 out of 1394
# Disintegrating [1, 5, 200]~[1, 8, 200] resting at z=100,100 supporting ['[1, 5, 201]~[1, 7, 201]', '[0, 8, 203]~[2, 8, 203]'] and supported by ['[1, 6, 199]~[1, 8, 199]']
# 406
# Brick 41 out of 1394
# Disintegrating [5, 9, 210]~[8, 9, 210] resting at z=105,105 supporting ['[8, 9, 211]~[9, 9, 211]'] and supported by ['[6, 6, 209]~[6, 9, 209]']
# 1
# Brick 42 out of 1394
# Disintegrating [2, 0, 28]~[2, 2, 28] resting at z=14,14 supporting ['[2, 0, 29]~[3, 0, 29]'] and supported by ['[2, 2, 27]~[2, 4, 27]']
# 1
# Brick 43 out of 1394
# Disintegrating [2, 5, 222]~[4, 5, 222] resting at z=110,110 supporting ['[4, 5, 225]~[4, 6, 225]', '[2, 4, 225]~[2, 7, 225]'] and supported by ['[4, 3, 221]~[4, 5, 221]']
# 34
# Brick 44 out of 1394
# Disintegrating [6, 7, 59]~[8, 7, 59] resting at z=27,27 supporting [] and supported by ['[6, 4, 56]~[6, 7, 56]']
# 0
# Brick 45 out of 1394
# Disintegrating [9, 8, 152]~[9, 9, 152] resting at z=81,81 supporting ['[9, 9, 153]~[9, 9, 155]'] and supported by ['[9, 6, 149]~[9, 8, 149]']
# 1
# Brick 46 out of 1394
# Disintegrating [0, 1, 205]~[0, 3, 205] resting at z=101,101 supporting ['[0, 2, 206]~[0, 4, 206]'] and supported by ['[0, 3, 204]~[2, 3, 204]']
# 3
# Brick 47 out of 1394
# Disintegrating [8, 7, 49]~[9, 7, 49] resting at z=23,23 supporting ['[9, 6, 50]~[9, 7, 50]'] and supported by ['[5, 7, 47]~[8, 7, 47]']
# 2
# Brick 48 out of 1394
# Disintegrating [4, 1, 44]~[4, 1, 47] resting at z=21,24 supporting ['[4, 1, 49]~[6, 1, 49]'] and supported by ['[4, 0, 43]~[4, 2, 43]']
# 15
# Brick 49 out of 1394
# Disintegrating [0, 5, 65]~[0, 7, 65] resting at z=29,29 supporting ['[0, 6, 68]~[0, 7, 68]'] and supported by ['[0, 5, 62]~[0, 8, 62]']
# 4
# Brick 50 out of 1394
# Disintegrating [2, 2, 303]~[2, 3, 303] resting at z=150,150 supporting ['[2, 2, 304]~[5, 2, 304]', '[2, 3, 304]~[4, 3, 304]'] and supported by ['[1, 2, 301]~[2, 2, 301]']
# 8
# Brick 51 out of 1394
# Disintegrating [6, 6, 21]~[6, 9, 21] resting at z=11,11 supporting ['[6, 5, 24]~[6, 7, 24]', '[4, 8, 24]~[6, 8, 24]'] and supported by ['[6, 6, 20]~[6, 9, 20]']
# 8
# Brick 52 out of 1394
# Disintegrating [4, 4, 99]~[4, 7, 99] resting at z=49,49 supporting ['[4, 4, 100]~[4, 4, 101]'] and supported by ['[3, 6, 96]~[5, 6, 96]']
# 3
# Brick 53 out of 1394
# Disintegrating [1, 0, 155]~[4, 0, 155] resting at z=74,74 supporting ['[4, 0, 158]~[6, 0, 158]', '[1, 0, 157]~[2, 0, 157]'] and supported by ['[2, 0, 152]~[3, 0, 152]']
# 6
# Brick 54 out of 1394
# Disintegrating [7, 5, 15]~[9, 5, 15] resting at z=7,7 supporting ['[8, 5, 16]~[9, 5, 16]'] and supported by ['[8, 5, 13]~[8, 8, 13]']
# 6
# Brick 55 out of 1394
# Disintegrating [4, 5, 232]~[4, 7, 232] resting at z=116,116 supporting ['[2, 5, 242]~[6, 5, 242]'] and supported by ['[3, 6, 231]~[6, 6, 231]']
# 0
# Brick 56 out of 1394
# Disintegrating [1, 9, 213]~[1, 9, 215] resting at z=106,108 supporting ['[0, 9, 218]~[3, 9, 218]'] and supported by ['[0, 9, 211]~[2, 9, 211]']
# 9
# Brick 57 out of 1394
# Disintegrating [1, 3, 105]~[1, 5, 105] resting at z=51,51 supporting [] and supported by ['[1, 3, 102]~[1, 5, 102]']
# 0
# Brick 58 out of 1394
# Disintegrating [4, 6, 197]~[4, 7, 197] resting at z=96,96 supporting [] and supported by ['[4, 5, 195]~[4, 7, 195]']
# 0
# Brick 59 out of 1394
# Disintegrating [0, 6, 235]~[0, 7, 235] resting at z=115,115 supporting ['[0, 6, 237]~[0, 6, 240]'] and supported by ['[0, 6, 233]~[0, 8, 233]']
# 1
# Brick 60 out of 1394
# Disintegrating [8, 4, 303]~[8, 6, 303] resting at z=154,154 supporting ['[8, 6, 306]~[8, 9, 306]'] and supported by ['[8, 4, 300]~[8, 6, 300]']
# 4
# Brick 61 out of 1394
# Disintegrating [3, 7, 62]~[5, 7, 62] resting at z=30,30 supporting ['[4, 7, 65]~[5, 7, 65]', '[3, 7, 64]~[3, 8, 64]'] and supported by ['[3, 6, 61]~[3, 9, 61]']
# 2
# Brick 62 out of 1394
# Disintegrating [4, 2, 279]~[7, 2, 279] resting at z=139,139 supporting ['[4, 2, 281]~[6, 2, 281]'] and supported by ['[7, 1, 277]~[7, 3, 277]']
# 50
# Brick 63 out of 1394
# Disintegrating [4, 0, 45]~[6, 0, 45] resting at z=21,21 supporting ['[5, 0, 46]~[8, 0, 46]'] and supported by ['[5, 0, 37]~[5, 0, 40]', '[4, 0, 43]~[4, 2, 43]']
# 1
# Brick 64 out of 1394
# Disintegrating [8, 7, 195]~[8, 9, 195] resting at z=99,99 supporting ['[8, 6, 196]~[8, 7, 196]'] and supported by ['[5, 7, 193]~[9, 7, 193]']
# 2
# Brick 65 out of 1394
# Disintegrating [1, 7, 88]~[5, 7, 88] resting at z=46,46 supporting ['[5, 5, 94]~[5, 8, 94]', '[3, 6, 91]~[3, 9, 91]'] and supported by ['[1, 6, 87]~[1, 8, 87]', '[2, 7, 87]~[2, 9, 87]']
# 1
# Brick 66 out of 1394
# Disintegrating [1, 0, 246]~[4, 0, 246] resting at z=120,120 supporting ['[2, 0, 247]~[5, 0, 247]', '[1, 0, 248]~[1, 2, 248]'] and supported by ['[1, 0, 244]~[3, 0, 244]']
# 8
# Brick 67 out of 1394
# Disintegrating [5, 6, 115]~[5, 6, 118] resting at z=56,59 supporting ['[4, 6, 121]~[6, 6, 121]'] and supported by ['[5, 6, 113]~[5, 8, 113]']
# 91
# Brick 68 out of 1394
# Disintegrating [3, 3, 25]~[3, 5, 25] resting at z=13,13 supporting ['[3, 5, 28]~[4, 5, 28]'] and supported by ['[1, 3, 24]~[4, 3, 24]']
# 1139
# Brick 69 out of 1394
# Disintegrating [1, 7, 261]~[4, 7, 261] resting at z=128,128 supporting ['[2, 5, 264]~[2, 8, 264]'] and supported by ['[4, 6, 259]~[4, 9, 259]']
# 0
# Brick 70 out of 1394
# Disintegrating [7, 3, 206]~[8, 3, 206] resting at z=104,104 supporting ['[8, 3, 209]~[8, 4, 209]'] and supported by ['[7, 2, 204]~[7, 4, 204]']
# 10
# Brick 71 out of 1394
# Disintegrating [4, 1, 49]~[6, 1, 49] resting at z=25,25 supporting ['[6, 0, 51]~[6, 1, 51]', '[2, 1, 51]~[4, 1, 51]'] and supported by ['[4, 1, 44]~[4, 1, 47]']
# 14
# Brick 72 out of 1394
# Disintegrating [7, 1, 179]~[9, 1, 179] resting at z=97,97 supporting ['[8, 1, 182]~[8, 1, 182]'] and supported by ['[7, 1, 176]~[7, 3, 176]']
# 5
# Brick 73 out of 1394
# Disintegrating [6, 1, 264]~[8, 1, 264] resting at z=126,126 supporting [] and supported by ['[8, 1, 263]~[8, 3, 263]', '[7, 0, 261]~[7, 2, 261]']
# 0
# Brick 74 out of 1394
# Disintegrating [1, 8, 205]~[4, 8, 205] resting at z=102,102 supporting ['[4, 8, 206]~[7, 8, 206]', '[1, 6, 207]~[1, 9, 207]', '[2, 7, 208]~[2, 9, 208]'] and supported by ['[0, 8, 203]~[2, 8, 203]']
# 398
# Brick 75 out of 1394
# Disintegrating [4, 5, 283]~[5, 5, 283] resting at z=140,140 supporting ['[2, 5, 286]~[5, 5, 286]'] and supported by ['[5, 5, 280]~[5, 7, 280]']
# 24
# Brick 76 out of 1394
# Disintegrating [3, 3, 208]~[3, 5, 208] resting at z=102,102 supporting [] and supported by ['[3, 2, 205]~[3, 5, 205]']
# 0
# Brick 77 out of 1394
# Disintegrating [4, 1, 101]~[4, 1, 102] resting at z=49,50 supporting ['[3, 1, 104]~[4, 1, 104]'] and supported by ['[3, 1, 98]~[6, 1, 98]']
# 2
# Brick 78 out of 1394
# Disintegrating [2, 2, 272]~[2, 2, 274] resting at z=132,134 supporting ['[0, 2, 276]~[3, 2, 276]'] and supported by ['[2, 2, 269]~[4, 2, 269]']
# 5
# Brick 79 out of 1394
# Disintegrating [4, 7, 43]~[4, 9, 43] resting at z=20,20 supporting ['[4, 7, 46]~[6, 7, 46]', '[4, 9, 45]~[7, 9, 45]'] and supported by ['[4, 6, 40]~[4, 8, 40]']
# 1121
# Brick 80 out of 1394
# Disintegrating [5, 7, 188]~[5, 9, 188] resting at z=96,96 supporting ['[5, 7, 191]~[5, 8, 191]', '[3, 9, 191]~[5, 9, 191]'] and supported by ['[3, 8, 176]~[6, 8, 176]']
# 20
# Brick 81 out of 1394
# Disintegrating [6, 8, 290]~[6, 9, 290] resting at z=144,144 supporting ['[5, 9, 293]~[7, 9, 293]'] and supported by ['[5, 8, 288]~[8, 8, 288]']
# 1
# Brick 82 out of 1394
# Disintegrating [3, 6, 111]~[6, 6, 111] resting at z=54,54 supporting ['[5, 6, 113]~[5, 8, 113]', '[4, 4, 114]~[4, 7, 114]', '[6, 6, 113]~[6, 8, 113]', '[3, 4, 112]~[3, 6, 112]'] and supported by ['[6, 4, 108]~[6, 6, 108]']
# 161
# Brick 83 out of 1394
# Disintegrating [3, 4, 230]~[5, 4, 230] resting at z=112,112 supporting ['[5, 1, 233]~[5, 4, 233]'] and supported by ['[4, 2, 227]~[4, 4, 227]']
# 30
# Brick 84 out of 1394
# Disintegrating [5, 7, 154]~[7, 7, 154] resting at z=82,82 supporting ['[5, 5, 156]~[5, 7, 156]'] and supported by ['[6, 7, 151]~[7, 7, 151]']
# 522
# Brick 85 out of 1394
# Disintegrating [8, 5, 83]~[9, 5, 83] resting at z=42,42 supporting ['[9, 4, 86]~[9, 5, 86]'] and supported by ['[8, 5, 82]~[8, 7, 82]']
# 0
# Brick 86 out of 1394
# Disintegrating [4, 2, 283]~[6, 2, 283] resting at z=142,142 supporting ['[2, 2, 285]~[4, 2, 285]', '[5, 2, 284]~[6, 2, 284]'] and supported by ['[4, 2, 282]~[5, 2, 282]']
# 47
# Brick 87 out of 1394
# Disintegrating [7, 3, 276]~[7, 6, 276] resting at z=137,137 supporting ['[5, 6, 277]~[8, 6, 277]', '[7, 1, 277]~[7, 3, 277]'] and supported by ['[5, 5, 275]~[7, 5, 275]']
# 135
# Brick 88 out of 1394
# Disintegrating [6, 0, 270]~[8, 0, 270] resting at z=130,130 supporting [] and supported by ['[5, 0, 269]~[7, 0, 269]']
# 0
# Brick 89 out of 1394
# Disintegrating [7, 7, 77]~[9, 7, 77] resting at z=38,38 supporting [] and supported by ['[7, 7, 76]~[9, 7, 76]']
# 0
# Brick 90 out of 1394
# Disintegrating [2, 0, 256]~[2, 0, 258] resting at z=125,127 supporting [] and supported by ['[0, 0, 255]~[2, 0, 255]']
# 0
# Brick 91 out of 1394
# Disintegrating [3, 3, 305]~[3, 5, 305] resting at z=152,152 supporting [] and supported by ['[2, 3, 304]~[4, 3, 304]', '[3, 5, 302]~[5, 5, 302]']
# 0
# Brick 92 out of 1394
# Disintegrating [9, 7, 87]~[9, 9, 87] resting at z=41,41 supporting ['[9, 7, 89]~[9, 9, 89]'] and supported by ['[7, 9, 86]~[9, 9, 86]']
# 1
# Brick 93 out of 1394
# Disintegrating [1, 9, 219]~[1, 9, 221] resting at z=110,112 supporting [] and supported by ['[0, 9, 218]~[3, 9, 218]']
# 0
# Brick 94 out of 1394
# Disintegrating [3, 3, 123]~[3, 6, 123] resting at z=61,61 supporting ['[1, 6, 125]~[3, 6, 125]', '[2, 4, 126]~[4, 4, 126]'] and supported by ['[2, 5, 120]~[3, 5, 120]']
# 7
# Brick 95 out of 1394
# Disintegrating [2, 2, 194]~[2, 2, 195] resting at z=96,97 supporting ['[2, 2, 196]~[2, 3, 196]'] and supported by ['[2, 1, 192]~[2, 4, 192]']
# 73
# Brick 96 out of 1394
# Disintegrating [7, 5, 64]~[7, 5, 67] resting at z=30,33 supporting ['[7, 3, 70]~[7, 6, 70]'] and supported by ['[6, 5, 63]~[8, 5, 63]']
# 1048
# Brick 97 out of 1394
# Disintegrating [1, 8, 89]~[1, 9, 89] resting at z=46,46 supporting ['[0, 9, 92]~[1, 9, 92]'] and supported by ['[1, 6, 87]~[1, 8, 87]']
# 1
# Brick 98 out of 1394
# Disintegrating [1, 0, 291]~[1, 2, 291] resting at z=144,144 supporting ['[0, 1, 293]~[3, 1, 293]', '[0, 0, 293]~[2, 0, 293]'] and supported by ['[1, 1, 289]~[1, 5, 289]']
# 21
# Brick 99 out of 1394
# Disintegrating [0, 9, 166]~[1, 9, 166] resting at z=82,82 supporting [] and supported by ['[1, 9, 165]~[1, 9, 165]']
# 0
# Brick 100 out of 1394
# Disintegrating [2, 6, 274]~[2, 9, 274] resting at z=134,134 supporting ['[1, 7, 275]~[4, 7, 275]'] and supported by ['[2, 7, 271]~[4, 7, 271]']
# 2
# Brick 101 out of 1394
# Disintegrating [0, 6, 17]~[0, 6, 20] resting at z=10,13 supporting ['[0, 6, 21]~[0, 9, 21]'] and supported by ['[0, 5, 16]~[0, 7, 16]']
# 2
# Brick 102 out of 1394
# Disintegrating [5, 6, 277]~[8, 6, 277] resting at z=138,138 supporting ['[5, 5, 280]~[5, 7, 280]', '[8, 5, 281]~[8, 7, 281]'] and supported by ['[7, 3, 276]~[7, 6, 276]']
# 29
# Brick 103 out of 1394
# Disintegrating [4, 2, 227]~[4, 4, 227] resting at z=111,111 supporting ['[3, 4, 230]~[5, 4, 230]', '[4, 1, 230]~[4, 3, 230]'] and supported by ['[4, 1, 224]~[4, 4, 224]']
# 32
# Brick 104 out of 1394
# Disintegrating [4, 6, 8]~[4, 7, 8] resting at z=4,4 supporting ['[3, 7, 11]~[5, 7, 11]'] and supported by ['[1, 7, 7]~[4, 7, 7]']
# 0
# Brick 105 out of 1394
# Disintegrating [5, 4, 84]~[7, 4, 84] resting at z=43,43 supporting ['[6, 3, 87]~[6, 5, 87]'] and supported by ['[6, 3, 83]~[6, 5, 83]']
# 3
# Brick 106 out of 1394
# Disintegrating [1, 6, 266]~[1, 9, 266] resting at z=132,132 supporting ['[1, 4, 267]~[1, 6, 267]', '[1, 7, 268]~[1, 8, 268]'] and supported by ['[1, 9, 263]~[1, 9, 265]']
# 3
# Brick 107 out of 1394
# Disintegrating [0, 7, 228]~[2, 7, 228] resting at z=112,112 supporting ['[1, 7, 230]~[2, 7, 230]', '[0, 6, 230]~[0, 7, 230]'] and supported by ['[2, 4, 225]~[2, 7, 225]']
# 5
# Brick 108 out of 1394
# Disintegrating [8, 5, 29]~[8, 8, 29] resting at z=15,15 supporting ['[7, 8, 30]~[9, 8, 30]', '[8, 3, 30]~[8, 5, 30]'] and supported by ['[8, 8, 26]~[8, 9, 26]']
# 4
# Brick 109 out of 1394
# Disintegrating [1, 9, 230]~[2, 9, 230] resting at z=114,114 supporting [] and supported by ['[2, 9, 228]~[4, 9, 228]']
# 0
# Brick 110 out of 1394
# Disintegrating [2, 1, 140]~[2, 3, 140] resting at z=69,69 supporting ['[2, 3, 143]~[4, 3, 143]'] and supported by ['[2, 2, 136]~[2, 2, 137]']
# 16
# Brick 111 out of 1394
# Disintegrating [1, 6, 3]~[3, 6, 3] resting at z=1,1 supporting [] and supported by []
# 0
# Brick 112 out of 1394
# Disintegrating [2, 8, 3]~[2, 9, 3] resting at z=1,1 supporting [] and supported by []
# 0
# Brick 113 out of 1394
# Disintegrating [4, 0, 161]~[4, 2, 161] resting at z=79,79 supporting ['[4, 0, 165]~[6, 0, 165]'] and supported by ['[4, 2, 156]~[4, 3, 156]']
# 3
# Brick 114 out of 1394
# Disintegrating [2, 6, 254]~[3, 6, 254] resting at z=123,123 supporting [] and supported by ['[3, 6, 252]~[5, 6, 252]']
# 0
# Brick 115 out of 1394
# Disintegrating [5, 0, 32]~[5, 2, 32] resting at z=15,15 supporting ['[2, 0, 35]~[5, 0, 35]', '[4, 1, 33]~[6, 1, 33]', '[2, 2, 33]~[5, 2, 33]'] and supported by ['[3, 1, 30]~[7, 1, 30]']
# 5
# Brick 116 out of 1394
# Disintegrating [4, 0, 205]~[4, 2, 205] resting at z=103,103 supporting ['[2, 1, 206]~[5, 1, 206]', '[3, 2, 209]~[5, 2, 209]'] and supported by ['[4, 0, 203]~[4, 1, 203]']
# 34
# Brick 117 out of 1394
# Disintegrating [0, 1, 161]~[1, 1, 161] resting at z=77,77 supporting ['[1, 0, 162]~[1, 1, 162]'] and supported by ['[1, 0, 158]~[1, 2, 158]']
# 1
# Brick 118 out of 1394
# Disintegrating [2, 0, 21]~[5, 0, 21] resting at z=11,11 supporting ['[5, 0, 26]~[5, 3, 26]'] and supported by ['[4, 0, 20]~[4, 1, 20]']
# 0
# Brick 119 out of 1394
# Disintegrating [3, 1, 132]~[5, 1, 132] resting at z=66,66 supporting ['[5, 1, 133]~[7, 1, 133]', '[4, 0, 133]~[4, 1, 133]'] and supported by ['[1, 1, 131]~[3, 1, 131]']
# 5
# Brick 120 out of 1394
# Disintegrating [9, 1, 10]~[9, 1, 10] resting at z=4,4 supporting [] and supported by ['[9, 1, 7]~[9, 3, 7]']
# 0
# Brick 121 out of 1394
# Disintegrating [7, 2, 89]~[7, 4, 89] resting at z=46,46 supporting [] and supported by ['[6, 4, 88]~[7, 4, 88]']
# 0
# Brick 122 out of 1394
# Disintegrating [6, 0, 170]~[9, 0, 170] resting at z=90,90 supporting ['[5, 0, 172]~[8, 0, 172]'] and supported by ['[7, 0, 167]~[7, 3, 167]']
# 2
# Brick 123 out of 1394
# Disintegrating [8, 0, 145]~[8, 3, 145] resting at z=76,76 supporting ['[8, 2, 146]~[8, 2, 147]'] and supported by ['[8, 3, 140]~[8, 3, 142]']
# 1
# Brick 124 out of 1394
# Disintegrating [1, 1, 5]~[3, 1, 5] resting at z=3,3 supporting [] and supported by ['[1, 0, 3]~[1, 3, 3]']
# 0
# Brick 125 out of 1394
# Disintegrating [3, 5, 13]~[3, 7, 13] resting at z=6,6 supporting [] and supported by ['[3, 7, 11]~[5, 7, 11]']
# 0
# Brick 126 out of 1394
# Disintegrating [3, 1, 30]~[7, 1, 30] resting at z=14,14 supporting ['[5, 0, 32]~[5, 2, 32]', '[6, 1, 32]~[6, 4, 32]'] and supported by ['[6, 1, 28]~[6, 4, 28]']
# 12
# Brick 127 out of 1394
# Disintegrating [7, 6, 175]~[7, 6, 178] resting at z=94,97 supporting [] and supported by ['[7, 6, 174]~[7, 9, 174]']
# 0
# Brick 128 out of 1394
# Disintegrating [8, 4, 3]~[8, 5, 3] resting at z=1,1 supporting ['[8, 5, 6]~[8, 7, 6]'] and supported by []
# 22
# Brick 129 out of 1394
# Disintegrating [5, 3, 113]~[7, 3, 113] resting at z=56,56 supporting ['[4, 3, 114]~[5, 3, 114]', '[7, 2, 118]~[7, 4, 118]'] and supported by ['[2, 3, 111]~[5, 3, 111]']
# 4
# Brick 130 out of 1394
# Disintegrating [2, 5, 120]~[3, 5, 120] resting at z=60,60 supporting ['[3, 3, 123]~[3, 6, 123]'] and supported by ['[2, 4, 118]~[2, 6, 118]']
# 8
# Brick 131 out of 1394
# Disintegrating [0, 0, 20]~[0, 3, 20] resting at z=9,9 supporting ['[0, 1, 22]~[0, 1, 23]'] and supported by ['[0, 2, 18]~[0, 3, 18]']
# 2
# Brick 132 out of 1394
# Disintegrating [5, 7, 47]~[8, 7, 47] resting at z=22,22 supporting ['[8, 7, 49]~[9, 7, 49]'] and supported by ['[4, 7, 46]~[6, 7, 46]']
# 3
# Brick 133 out of 1394
# Disintegrating [3, 5, 171]~[3, 5, 173] resting at z=86,88 supporting [] and supported by ['[3, 4, 170]~[3, 6, 170]']
# 0
# Brick 134 out of 1394
# Disintegrating [5, 4, 128]~[5, 7, 128] resting at z=65,65 supporting ['[4, 4, 129]~[6, 4, 129]'] and supported by ['[5, 6, 126]~[5, 7, 126]']
# 1
# Brick 135 out of 1394
# Disintegrating [8, 9, 211]~[9, 9, 211] resting at z=106,106 supporting [] and supported by ['[5, 9, 210]~[8, 9, 210]']
# 0
# Brick 136 out of 1394
# Disintegrating [3, 1, 297]~[5, 1, 297] resting at z=148,148 supporting ['[4, 1, 298]~[6, 1, 298]'] and supported by ['[4, 1, 296]~[4, 4, 296]']
# 1
# Brick 137 out of 1394
# Disintegrating [1, 9, 102]~[3, 9, 102] resting at z=53,53 supporting ['[1, 8, 105]~[1, 9, 105]'] and supported by ['[3, 7, 101]~[3, 9, 101]']
# 1
# Brick 138 out of 1394
# Disintegrating [4, 2, 47]~[4, 2, 47] resting at z=22,22 supporting [] and supported by ['[1, 2, 45]~[4, 2, 45]']
# 0
# Brick 139 out of 1394
# Disintegrating [4, 6, 302]~[4, 9, 302] resting at z=150,150 supporting ['[3, 7, 305]~[5, 7, 305]'] and supported by ['[2, 7, 300]~[4, 7, 300]']
# 1
# Brick 140 out of 1394
# Disintegrating [9, 3, 88]~[9, 3, 90] resting at z=44,46 supporting ['[9, 3, 91]~[9, 3, 94]'] and supported by ['[9, 2, 85]~[9, 3, 85]']
# 1
# Brick 141 out of 1394
# Disintegrating [5, 0, 26]~[5, 3, 26] resting at z=12,12 supporting [] and supported by ['[2, 0, 21]~[5, 0, 21]', '[4, 1, 23]~[7, 1, 23]']
# 0
# Brick 142 out of 1394
# Disintegrating [7, 1, 84]~[8, 1, 84] resting at z=42,42 supporting ['[8, 0, 87]~[8, 2, 87]'] and supported by ['[8, 0, 80]~[8, 2, 80]', '[7, 0, 81]~[7, 2, 81]']
# 0
# Brick 143 out of 1394
# Disintegrating [8, 1, 263]~[8, 3, 263] resting at z=125,125 supporting ['[6, 1, 264]~[8, 1, 264]'] and supported by ['[6, 2, 259]~[9, 2, 259]']
# 0
# Brick 144 out of 1394
# Disintegrating [8, 0, 95]~[9, 0, 95] resting at z=46,46 supporting [] and supported by ['[8, 0, 92]~[8, 3, 92]']
# 0
# Brick 145 out of 1394
# Disintegrating [2, 4, 116]~[2, 6, 116] resting at z=58,58 supporting ['[2, 4, 118]~[2, 6, 118]'] and supported by ['[0, 4, 115]~[2, 4, 115]']
# 10
# Brick 146 out of 1394
# Disintegrating [6, 4, 171]~[8, 4, 171] resting at z=93,93 supporting ['[6, 2, 173]~[6, 4, 173]', '[7, 1, 172]~[7, 4, 172]', '[8, 2, 174]~[8, 5, 174]'] and supported by ['[7, 4, 170]~[9, 4, 170]']
# 27
# Brick 147 out of 1394
# Disintegrating [7, 4, 245]~[7, 7, 245] resting at z=117,117 supporting ['[7, 7, 246]~[9, 7, 246]', '[6, 5, 248]~[8, 5, 248]', '[6, 6, 248]~[7, 6, 248]'] and supported by ['[5, 4, 242]~[7, 4, 242]']
# 19
# Brick 148 out of 1394
# Disintegrating [4, 1, 33]~[6, 1, 33] resting at z=16,16 supporting ['[6, 1, 35]~[8, 1, 35]'] and supported by ['[6, 1, 32]~[6, 4, 32]', '[5, 0, 32]~[5, 2, 32]']
# 1
# Brick 149 out of 1394
# Disintegrating [2, 2, 147]~[2, 4, 147] resting at z=72,72 supporting ['[1, 2, 150]~[4, 2, 150]'] and supported by ['[2, 3, 146]~[4, 3, 146]']
# 0
# Brick 150 out of 1394
# Disintegrating [0, 2, 276]~[3, 2, 276] resting at z=135,135 supporting ['[0, 1, 278]~[0, 2, 278]', '[1, 2, 278]~[1, 3, 278]'] and supported by ['[2, 2, 272]~[2, 2, 274]']
# 4
# Brick 151 out of 1394
# Disintegrating [5, 2, 266]~[8, 2, 266] resting at z=127,127 supporting [] and supported by ['[7, 2, 263]~[7, 2, 263]']
# 0
# Brick 152 out of 1394
# Disintegrating [1, 3, 274]~[3, 3, 274] resting at z=134,134 supporting ['[2, 3, 276]~[2, 5, 276]'] and supported by ['[2, 3, 272]~[2, 3, 273]']
# 11
# Brick 153 out of 1394
# Disintegrating [3, 6, 193]~[3, 6, 196] resting at z=95,98 supporting ['[3, 4, 199]~[3, 7, 199]'] and supported by ['[2, 6, 192]~[4, 6, 192]']
# 0
# Brick 154 out of 1394
# Disintegrating [0, 2, 35]~[3, 2, 35] resting at z=17,17 supporting ['[0, 2, 37]~[0, 3, 37]'] and supported by ['[2, 2, 33]~[5, 2, 33]']
# 3
# Brick 155 out of 1394
# Disintegrating [5, 4, 311]~[5, 5, 311] resting at z=157,157 supporting [] and supported by ['[5, 4, 309]~[7, 4, 309]']
# 0
# Brick 156 out of 1394
# Disintegrating [6, 2, 274]~[6, 5, 274] resting at z=135,135 supporting ['[5, 5, 275]~[7, 5, 275]', '[5, 4, 277]~[6, 4, 277]'] and supported by ['[5, 3, 273]~[7, 3, 273]']
# 140
# Brick 157 out of 1394
# Disintegrating [9, 0, 126]~[9, 2, 126] resting at z=68,68 supporting ['[8, 1, 128]~[9, 1, 128]', '[8, 2, 128]~[9, 2, 128]'] and supported by ['[8, 0, 125]~[9, 0, 125]']
# 663
# Brick 158 out of 1394
# Disintegrating [3, 4, 112]~[3, 6, 112] resting at z=55,55 supporting ['[0, 4, 113]~[3, 4, 113]'] and supported by ['[3, 6, 111]~[6, 6, 111]']
# 63
# Brick 159 out of 1394
# Disintegrating [5, 5, 163]~[8, 5, 163] resting at z=88,88 supporting ['[8, 4, 164]~[8, 6, 164]'] and supported by ['[8, 2, 162]~[8, 5, 162]']
# 71
# Brick 160 out of 1394
# Disintegrating [6, 0, 88]~[8, 0, 88] resting at z=44,44 supporting ['[8, 0, 92]~[8, 3, 92]'] and supported by ['[8, 0, 87]~[8, 2, 87]']
# 0
# Brick 161 out of 1394
# Disintegrating [4, 0, 214]~[7, 0, 214] resting at z=107,107 supporting ['[7, 0, 215]~[9, 0, 215]', '[5, 0, 215]~[6, 0, 215]'] and supported by ['[2, 0, 210]~[4, 0, 210]']
# 4
# Brick 162 out of 1394
# Disintegrating [5, 2, 35]~[7, 2, 35] resting at z=17,17 supporting ['[7, 2, 38]~[9, 2, 38]'] and supported by ['[2, 2, 33]~[5, 2, 33]', '[6, 2, 33]~[6, 4, 33]']
# 1
# Brick 163 out of 1394
# Disintegrating [4, 8, 66]~[7, 8, 66] resting at z=31,31 supporting ['[5, 8, 68]~[6, 8, 68]'] and supported by ['[3, 8, 63]~[4, 8, 63]']
# 1
# Brick 164 out of 1394
# Disintegrating [0, 8, 165]~[1, 8, 165] resting at z=81,81 supporting ['[1, 8, 168]~[3, 8, 168]'] and supported by ['[1, 7, 164]~[1, 9, 164]']
# 3
# Brick 165 out of 1394
# Disintegrating [0, 6, 180]~[2, 6, 180] resting at z=89,89 supporting ['[2, 6, 183]~[4, 6, 183]', '[0, 6, 181]~[0, 8, 181]'] and supported by ['[1, 6, 176]~[3, 6, 176]']
# 510
# Brick 166 out of 1394
# Disintegrating [4, 0, 104]~[6, 0, 104] resting at z=51,51 supporting ['[3, 0, 106]~[4, 0, 106]'] and supported by ['[4, 0, 102]~[7, 0, 102]']
# 2
# Brick 167 out of 1394
# Disintegrating [0, 5, 270]~[0, 8, 270] resting at z=133,133 supporting ['[0, 8, 272]~[0, 8, 274]'] and supported by ['[0, 4, 268]~[0, 7, 268]']
# 1
# Brick 168 out of 1394
# Disintegrating [4, 2, 73]~[4, 4, 73] resting at z=33,33 supporting ['[3, 4, 75]~[4, 4, 75]', '[2, 2, 74]~[4, 2, 74]'] and supported by ['[4, 3, 70]~[4, 6, 70]']
# 2
# Brick 169 out of 1394
# Disintegrating [3, 2, 17]~[5, 2, 17] resting at z=8,8 supporting ['[4, 0, 18]~[4, 2, 18]'] and supported by ['[0, 2, 15]~[4, 2, 15]']
# 5
# Brick 170 out of 1394
# Disintegrating [1, 5, 168]~[3, 5, 168] resting at z=81,81 supporting ['[2, 5, 169]~[2, 5, 169]', '[1, 4, 169]~[1, 7, 169]'] and supported by ['[2, 3, 165]~[2, 7, 165]']
# 4
# Brick 171 out of 1394
# Disintegrating [7, 7, 22]~[8, 7, 22] resting at z=11,11 supporting ['[8, 6, 23]~[8, 7, 23]'] and supported by ['[7, 5, 20]~[7, 7, 20]']
# 2
# Brick 172 out of 1394
# Disintegrating [6, 3, 2]~[6, 5, 2] resting at z=1,1 supporting ['[5, 3, 3]~[8, 3, 3]'] and supported by []
# 13
# Brick 173 out of 1394
# Disintegrating [8, 3, 123]~[8, 5, 123] resting at z=65,65 supporting ['[8, 5, 125]~[9, 5, 125]'] and supported by ['[8, 3, 120]~[8, 4, 120]']
# 1
# Brick 174 out of 1394
# Disintegrating [6, 9, 142]~[6, 9, 143] resting at z=69,70 supporting [] and supported by ['[4, 9, 139]~[7, 9, 139]']
# 0
# Brick 175 out of 1394
# Disintegrating [7, 1, 310]~[9, 1, 310] resting at z=156,156 supporting ['[9, 1, 313]~[9, 3, 313]'] and supported by ['[7, 1, 307]~[7, 4, 307]']
# 11
# Brick 176 out of 1394
# Disintegrating [7, 1, 203]~[7, 4, 203] resting at z=102,102 supporting ['[7, 2, 204]~[7, 4, 204]'] and supported by ['[5, 1, 201]~[7, 1, 201]']
# 12
# Brick 177 out of 1394
# Disintegrating [5, 3, 272]~[5, 7, 272] resting at z=133,133 supporting ['[5, 3, 273]~[7, 3, 273]', '[5, 4, 274]~[5, 6, 274]'] and supported by ['[4, 5, 270]~[7, 5, 270]']
# 143
# Brick 178 out of 1394
# Disintegrating [1, 3, 22]~[1, 3, 22] resting at z=11,11 supporting ['[1, 3, 24]~[4, 3, 24]'] and supported by ['[1, 2, 19]~[1, 4, 19]']
# 1157
# Brick 179 out of 1394
# Disintegrating [0, 9, 153]~[3, 9, 153] resting at z=74,74 supporting ['[2, 9, 156]~[3, 9, 156]'] and supported by ['[0, 5, 150]~[0, 9, 150]']
# 2
# Brick 180 out of 1394
# Disintegrating [2, 3, 285]~[4, 3, 285] resting at z=141,141 supporting ['[1, 3, 288]~[4, 3, 288]'] and supported by ['[4, 3, 282]~[6, 3, 282]']
# 25
# Brick 181 out of 1394
# Disintegrating [1, 0, 56]~[1, 3, 56] resting at z=28,28 supporting ['[0, 0, 57]~[3, 0, 57]'] and supported by ['[0, 1, 53]~[2, 1, 53]']
# 7
# Brick 182 out of 1394
# Disintegrating [1, 8, 105]~[1, 9, 105] resting at z=54,54 supporting [] and supported by ['[1, 9, 102]~[3, 9, 102]']
# 0
# Brick 183 out of 1394
# Disintegrating [8, 1, 128]~[9, 1, 128] resting at z=69,69 supporting ['[8, 1, 131]~[8, 5, 131]'] and supported by ['[9, 0, 126]~[9, 2, 126]']
# 0
# Brick 184 out of 1394
# Disintegrating [1, 0, 13]~[1, 0, 16] resting at z=6,9 supporting [] and supported by ['[1, 0, 11]~[1, 2, 11]']
# 0
# Brick 185 out of 1394
# Disintegrating [0, 6, 153]~[0, 8, 153] resting at z=75,75 supporting [] and supported by ['[0, 6, 151]~[0, 7, 151]']
# 0
# Brick 186 out of 1394
# Disintegrating [2, 5, 95]~[2, 7, 95] resting at z=49,49 supporting ['[2, 5, 98]~[2, 7, 98]'] and supported by ['[2, 6, 92]~[2, 6, 94]']
# 6
# Brick 187 out of 1394
# Disintegrating [6, 8, 265]~[8, 8, 265] resting at z=129,129 supporting ['[7, 8, 268]~[9, 8, 268]'] and supported by ['[6, 8, 262]~[6, 8, 264]']
# 1
# Brick 188 out of 1394
# Disintegrating [2, 1, 200]~[5, 1, 200] resting at z=100,100 supporting ['[5, 1, 201]~[7, 1, 201]', '[4, 1, 201]~[4, 3, 201]', '[2, 1, 202]~[3, 1, 202]'] and supported by ['[2, 0, 198]~[2, 2, 198]']
# 53
# Brick 189 out of 1394
# Disintegrating [4, 2, 307]~[4, 2, 309] resting at z=152,154 supporting ['[2, 2, 312]~[4, 2, 312]'] and supported by ['[2, 2, 304]~[5, 2, 304]']
# 5
# Brick 190 out of 1394
# Disintegrating [1, 0, 243]~[3, 0, 243] resting at z=118,118 supporting ['[1, 0, 244]~[3, 0, 244]'] and supported by ['[2, 0, 240]~[2, 2, 240]']
# 10
# Brick 191 out of 1394
# Disintegrating [7, 1, 307]~[7, 4, 307] resting at z=155,155 supporting ['[7, 1, 310]~[9, 1, 310]', '[5, 4, 309]~[7, 4, 309]'] and supported by ['[6, 3, 304]~[9, 3, 304]']
# 14
# Brick 192 out of 1394
# Disintegrating [3, 5, 99]~[3, 5, 102] resting at z=50,53 supporting [] and supported by ['[3, 5, 98]~[3, 8, 98]']
# 0
# Brick 193 out of 1394
# Disintegrating [3, 0, 106]~[4, 0, 106] resting at z=52,52 supporting ['[3, 0, 108]~[4, 0, 108]'] and supported by ['[4, 0, 104]~[6, 0, 104]']
# 1
# Brick 194 out of 1394
# Disintegrating [0, 1, 321]~[3, 1, 321] resting at z=163,163 supporting ['[3, 1, 324]~[5, 1, 324]'] and supported by ['[3, 1, 318]~[4, 1, 318]']
# 1
# Brick 195 out of 1394
# Disintegrating [2, 3, 199]~[2, 4, 199] resting at z=99,99 supporting ['[0, 4, 204]~[2, 4, 204]', '[0, 3, 204]~[2, 3, 204]'] and supported by ['[2, 2, 196]~[2, 3, 196]']
# 6
# Brick 196 out of 1394
# Disintegrating [6, 0, 283]~[6, 1, 283] resting at z=141,141 supporting ['[5, 0, 285]~[7, 0, 285]'] and supported by ['[5, 1, 282]~[7, 1, 282]']
# 2
# Brick 197 out of 1394
# Disintegrating [7, 2, 38]~[9, 2, 38] resting at z=18,18 supporting [] and supported by ['[5, 2, 35]~[7, 2, 35]']
# 0
# Brick 198 out of 1394
# Disintegrating [8, 5, 16]~[9, 5, 16] resting at z=8,8 supporting ['[9, 3, 19]~[9, 5, 19]'] and supported by ['[7, 5, 15]~[9, 5, 15]']
# 5
# Brick 199 out of 1394
# Disintegrating [0, 2, 37]~[0, 3, 37] resting at z=18,18 supporting ['[0, 3, 40]~[0, 5, 40]'] and supported by ['[0, 2, 35]~[3, 2, 35]']
# 2
# Brick 200 out of 1394
# Disintegrating [2, 2, 312]~[4, 2, 312] resting at z=155,155 supporting ['[2, 2, 315]~[2, 5, 315]', '[3, 2, 313]~[4, 2, 313]'] and supported by ['[4, 2, 307]~[4, 2, 309]']
# 4
# Brick 201 out of 1394
# Disintegrating [6, 1, 225]~[6, 3, 225] resting at z=111,111 supporting [] and supported by ['[6, 3, 223]~[6, 5, 223]']
# 0
# Brick 202 out of 1394
# Disintegrating [1, 9, 263]~[1, 9, 265] resting at z=129,131 supporting ['[1, 6, 266]~[1, 9, 266]'] and supported by ['[1, 9, 261]~[4, 9, 261]']
# 4
# Brick 203 out of 1394
# Disintegrating [1, 6, 87]~[1, 8, 87] resting at z=45,45 supporting ['[1, 8, 89]~[1, 9, 89]', '[1, 7, 88]~[5, 7, 88]', '[1, 6, 89]~[1, 6, 91]'] and supported by ['[0, 7, 86]~[3, 7, 86]']
# 3
# Brick 204 out of 1394
# Disintegrating [4, 6, 40]~[4, 8, 40] resting at z=19,19 supporting ['[4, 7, 43]~[4, 9, 43]', '[4, 6, 41]~[6, 6, 41]'] and supported by ['[3, 7, 37]~[5, 7, 37]']
# 1125
# Brick 205 out of 1394
# Disintegrating [4, 9, 45]~[7, 9, 45] resting at z=21,21 supporting ['[5, 9, 47]~[8, 9, 47]'] and supported by ['[4, 7, 43]~[4, 9, 43]']
# 2
# Brick 206 out of 1394
# Disintegrating [3, 1, 177]~[3, 1, 178] resting at z=97,98 supporting [] and supported by ['[3, 1, 176]~[5, 1, 176]']
# 0
# Brick 207 out of 1394
# Disintegrating [8, 7, 14]~[9, 7, 14] resting at z=7,7 supporting ['[9, 7, 15]~[9, 9, 15]'] and supported by ['[8, 5, 13]~[8, 8, 13]']
# 1
# Brick 208 out of 1394
# Disintegrating [4, 8, 214]~[7, 8, 214] resting at z=106,106 supporting ['[6, 8, 216]~[9, 8, 216]'] and supported by ['[2, 8, 211]~[4, 8, 211]']
# 6
# Brick 209 out of 1394
# Disintegrating [4, 7, 224]~[4, 9, 224] resting at z=111,111 supporting ['[4, 9, 226]~[6, 9, 226]'] and supported by ['[2, 9, 221]~[4, 9, 221]']
# 5
# Brick 210 out of 1394
# Disintegrating [1, 2, 245]~[1, 3, 245] resting at z=119,119 supporting [] and supported by ['[0, 2, 243]~[2, 2, 243]']
# 0
# Brick 211 out of 1394
# Disintegrating [8, 3, 260]~[8, 6, 260] resting at z=123,123 supporting ['[8, 6, 262]~[8, 6, 265]'] and supported by ['[8, 6, 257]~[8, 7, 257]']
# 1
# Brick 212 out of 1394
# Disintegrating [7, 7, 278]~[7, 8, 278] resting at z=136,136 supporting ['[6, 7, 279]~[7, 7, 279]'] and supported by ['[6, 7, 276]~[8, 7, 276]']
# 2
# Brick 213 out of 1394
# Disintegrating [3, 6, 212]~[7, 6, 212] resting at z=106,106 supporting ['[5, 5, 215]~[5, 7, 215]'] and supported by ['[4, 4, 209]~[4, 6, 209]']
# 368
# Brick 214 out of 1394
# Disintegrating [0, 2, 18]~[0, 3, 18] resting at z=8,8 supporting ['[0, 0, 20]~[0, 3, 20]'] and supported by ['[0, 2, 15]~[4, 2, 15]']
# 3
# Brick 215 out of 1394
# Disintegrating [4, 6, 122]~[6, 6, 122] resting at z=61,61 supporting ['[5, 6, 123]~[5, 8, 123]', '[6, 6, 123]~[6, 8, 123]'] and supported by ['[4, 6, 121]~[6, 6, 121]']
# 89
# Brick 216 out of 1394
# Disintegrating [2, 5, 12]~[2, 6, 12] resting at z=5,5 supporting ['[2, 6, 15]~[2, 6, 15]'] and supported by ['[2, 6, 10]~[2, 8, 10]']
# 1
# Brick 217 out of 1394
# Disintegrating [7, 6, 275]~[7, 9, 275] resting at z=134,134 supporting ['[6, 7, 276]~[8, 7, 276]'] and supported by ['[6, 8, 274]~[9, 8, 274]']
# 5
# Brick 218 out of 1394
# Disintegrating [5, 5, 249]~[8, 5, 249] resting at z=119,119 supporting [] and supported by ['[5, 4, 244]~[5, 6, 244]', '[6, 5, 248]~[8, 5, 248]']
# 0
# Brick 219 out of 1394
# Disintegrating [6, 2, 83]~[9, 2, 83] resting at z=42,42 supporting ['[9, 2, 85]~[9, 3, 85]', '[8, 0, 87]~[8, 2, 87]'] and supported by ['[7, 0, 81]~[7, 2, 81]', '[6, 2, 76]~[6, 2, 79]', '[8, 0, 80]~[8, 2, 80]']
# 0
# Brick 220 out of 1394
# Disintegrating [4, 2, 316]~[6, 2, 316] resting at z=157,157 supporting [] and supported by ['[3, 2, 313]~[4, 2, 313]']
# 0
# Brick 221 out of 1394
# Disintegrating [2, 6, 15]~[2, 6, 15] resting at z=6,6 supporting [] and supported by ['[2, 5, 12]~[2, 6, 12]']
# 0
# Brick 222 out of 1394
# Disintegrating [6, 6, 248]~[7, 6, 248] resting at z=118,118 supporting ['[6, 6, 249]~[9, 6, 249]'] and supported by ['[7, 4, 245]~[7, 7, 245]']
# 3
# Brick 223 out of 1394
# Disintegrating [7, 3, 280]~[9, 3, 280] resting at z=140,140 supporting ['[7, 3, 283]~[7, 5, 283]', '[9, 2, 281]~[9, 3, 281]'] and supported by ['[5, 3, 279]~[7, 3, 279]']
# 3
# Brick 224 out of 1394
# Disintegrating [4, 8, 275]~[6, 8, 275] resting at z=134,134 supporting [] and supported by ['[6, 8, 274]~[9, 8, 274]', '[3, 8, 271]~[4, 8, 271]']
# 0
# Brick 225 out of 1394
# Disintegrating [0, 0, 77]~[0, 2, 77] resting at z=34,34 supporting ['[0, 0, 79]~[0, 2, 79]'] and supported by ['[0, 0, 74]~[0, 2, 74]']
# 5
# Brick 226 out of 1394
# Disintegrating [6, 5, 63]~[8, 5, 63] resting at z=29,29 supporting ['[7, 5, 64]~[7, 5, 67]', '[8, 3, 64]~[8, 6, 64]'] and supported by ['[7, 5, 60]~[9, 5, 60]']
# 1062
# Brick 227 out of 1394
# Disintegrating [5, 0, 37]~[5, 0, 40] resting at z=17,20 supporting ['[4, 0, 45]~[6, 0, 45]'] and supported by ['[2, 0, 35]~[5, 0, 35]']
# 0
# Brick 228 out of 1394
# Disintegrating [6, 1, 75]~[6, 4, 75] resting at z=37,37 supporting ['[6, 0, 77]~[6, 1, 77]', '[6, 3, 76]~[9, 3, 76]', '[6, 2, 76]~[6, 2, 79]', '[6, 4, 77]~[6, 4, 77]'] and supported by ['[5, 2, 72]~[7, 2, 72]', '[6, 3, 73]~[7, 3, 73]']
# 4
# Brick 229 out of 1394
# Disintegrating [4, 0, 38]~[4, 0, 40] resting at z=17,19 supporting ['[4, 0, 43]~[4, 2, 43]'] and supported by ['[2, 0, 35]~[5, 0, 35]']
# 33
# Brick 230 out of 1394
# Disintegrating [0, 8, 99]~[3, 8, 99] resting at z=50,50 supporting [] and supported by ['[3, 5, 98]~[3, 8, 98]']
# 0
# Brick 231 out of 1394
# Disintegrating [4, 1, 298]~[6, 1, 298] resting at z=149,149 supporting ['[2, 1, 299]~[4, 1, 299]'] and supported by ['[3, 1, 297]~[5, 1, 297]']
# 0
# Brick 232 out of 1394
# Disintegrating [7, 8, 268]~[9, 8, 268] resting at z=130,130 supporting [] and supported by ['[6, 8, 265]~[8, 8, 265]']
# 0
# Brick 233 out of 1394
# Disintegrating [9, 1, 313]~[9, 3, 313] resting at z=157,157 supporting ['[7, 2, 314]~[9, 2, 314]'] and supported by ['[7, 1, 310]~[9, 1, 310]']
# 10
# Brick 234 out of 1394
# Disintegrating [4, 8, 24]~[6, 8, 24] resting at z=12,12 supporting ['[6, 8, 25]~[8, 8, 25]'] and supported by ['[6, 6, 21]~[6, 9, 21]']
# 7
# Brick 235 out of 1394
# Disintegrating [5, 6, 264]~[5, 9, 264] resting at z=130,130 supporting ['[3, 9, 265]~[5, 9, 265]', '[5, 5, 267]~[5, 8, 267]'] and supported by ['[5, 5, 261]~[5, 8, 261]']
# 159
# Brick 236 out of 1394
# Disintegrating [8, 3, 32]~[8, 5, 32] resting at z=17,17 supporting [] and supported by ['[8, 3, 30]~[8, 5, 30]']
# 0
# Brick 237 out of 1394
# Disintegrating [2, 0, 205]~[2, 0, 207] resting at z=103,105 supporting ['[2, 0, 210]~[4, 0, 210]'] and supported by ['[2, 0, 203]~[2, 0, 203]']
# 6
# Brick 238 out of 1394
# Disintegrating [0, 2, 8]~[2, 2, 8] resting at z=4,4 supporting ['[0, 1, 10]~[0, 3, 10]', '[2, 2, 11]~[4, 2, 11]', '[1, 0, 11]~[1, 2, 11]'] and supported by ['[1, 2, 5]~[1, 5, 5]']
# 3
# Brick 239 out of 1394
# Disintegrating [2, 7, 102]~[2, 7, 104] resting at z=52,54 supporting [] and supported by ['[1, 7, 100]~[4, 7, 100]']
# 0
# Brick 240 out of 1394
# Disintegrating [1, 8, 239]~[2, 8, 239] resting at z=117,117 supporting [] and supported by ['[1, 6, 236]~[1, 8, 236]']
# 0
# Brick 241 out of 1394
# Disintegrating [8, 6, 201]~[9, 6, 201] resting at z=102,102 supporting ['[9, 5, 202]~[9, 6, 202]'] and supported by ['[9, 3, 199]~[9, 6, 199]', '[8, 6, 199]~[8, 7, 199]']
# 1
# Brick 242 out of 1394
# Disintegrating [2, 1, 202]~[3, 1, 202] resting at z=101,101 supporting [] and supported by ['[2, 1, 200]~[5, 1, 200]']
# 0
# Brick 243 out of 1394
# Disintegrating [3, 9, 62]~[5, 9, 62] resting at z=30,30 supporting ['[3, 9, 64]~[3, 9, 66]', '[4, 9, 64]~[6, 9, 64]'] and supported by ['[3, 6, 61]~[3, 9, 61]']
# 4
# Brick 244 out of 1394
# Disintegrating [8, 5, 8]~[8, 5, 10] resting at z=3,5 supporting ['[8, 5, 13]~[8, 8, 13]'] and supported by ['[8, 5, 6]~[8, 7, 6]']
# 19
# Brick 245 out of 1394
# Disintegrating [3, 9, 158]~[4, 9, 158] resting at z=76,76 supporting [] and supported by ['[2, 9, 156]~[3, 9, 156]']
# 0
# Brick 246 out of 1394
# Disintegrating [9, 2, 143]~[9, 4, 143] resting at z=75,75 supporting ['[9, 2, 146]~[9, 5, 146]'] and supported by ['[9, 4, 141]~[9, 6, 141]']
# 3
# Brick 247 out of 1394
# Disintegrating [8, 4, 81]~[8, 6, 81] resting at z=40,40 supporting ['[8, 4, 83]~[8, 4, 85]', '[8, 5, 82]~[8, 7, 82]'] and supported by ['[5, 5, 78]~[8, 5, 78]']
# 3
# Brick 248 out of 1394
# Disintegrating [3, 9, 2]~[3, 9, 2] resting at z=1,1 supporting [] and supported by []
# 0
# Brick 249 out of 1394
# Disintegrating [4, 4, 67]~[6, 4, 67] resting at z=31,31 supporting ['[4, 3, 70]~[4, 6, 70]'] and supported by ['[4, 4, 64]~[6, 4, 64]']
# 4
# Brick 250 out of 1394
# Disintegrating [3, 4, 199]~[3, 7, 199] resting at z=99,99 supporting ['[3, 5, 202]~[6, 5, 202]'] and supported by ['[3, 4, 195]~[4, 4, 195]', '[3, 6, 193]~[3, 6, 196]']
# 0
# Brick 251 out of 1394
# Disintegrating [6, 8, 274]~[9, 8, 274] resting at z=133,133 supporting ['[7, 6, 275]~[7, 9, 275]', '[9, 6, 277]~[9, 9, 277]', '[4, 8, 275]~[6, 8, 275]'] and supported by ['[5, 8, 271]~[7, 8, 271]']
# 7
# Brick 252 out of 1394
# Disintegrating [6, 5, 58]~[8, 5, 58] resting at z=27,27 supporting ['[7, 5, 60]~[9, 5, 60]'] and supported by ['[6, 4, 56]~[6, 7, 56]']
# 1066
# Brick 253 out of 1394
# Disintegrating [9, 3, 28]~[9, 6, 28] resting at z=14,14 supporting ['[9, 4, 29]~[9, 4, 31]'] and supported by ['[9, 4, 21]~[9, 4, 24]']
# 1
# Brick 254 out of 1394
# Disintegrating [3, 1, 104]~[4, 1, 104] resting at z=51,51 supporting ['[3, 1, 107]~[3, 2, 107]'] and supported by ['[4, 1, 101]~[4, 1, 102]']
# 1
# Brick 255 out of 1394
# Disintegrating [8, 6, 23]~[8, 7, 23] resting at z=12,12 supporting ['[8, 4, 25]~[8, 6, 25]'] and supported by ['[7, 7, 22]~[8, 7, 22]']
# 1
# Brick 256 out of 1394
# Disintegrating [2, 9, 136]~[4, 9, 136] resting at z=67,67 supporting ['[4, 9, 139]~[7, 9, 139]'] and supported by ['[1, 9, 133]~[4, 9, 133]']
# 4
# Brick 257 out of 1394
# Disintegrating [7, 0, 167]~[7, 3, 167] resting at z=89,89 supporting ['[6, 0, 170]~[9, 0, 170]', '[4, 1, 170]~[7, 1, 170]'] and supported by ['[5, 2, 166]~[8, 2, 166]', '[6, 3, 164]~[9, 3, 164]']
# 4
# Brick 258 out of 1394
# Disintegrating [5, 3, 11]~[7, 3, 11] resting at z=6,6 supporting ['[6, 3, 12]~[7, 3, 12]'] and supported by ['[7, 3, 10]~[7, 4, 10]']
# 3
# Brick 259 out of 1394
# Disintegrating [6, 2, 76]~[6, 2, 79] resting at z=38,41 supporting ['[6, 2, 83]~[9, 2, 83]'] and supported by ['[6, 1, 75]~[6, 4, 75]']
# 0
# Brick 260 out of 1394
# Disintegrating [9, 0, 216]~[9, 2, 216] resting at z=109,109 supporting [] and supported by ['[7, 0, 215]~[9, 0, 215]', '[9, 1, 214]~[9, 4, 214]']
# 0
# Brick 261 out of 1394
# Disintegrating [3, 2, 255]~[3, 3, 255] resting at z=123,123 supporting [] and supported by ['[3, 3, 254]~[6, 3, 254]']
# 0
# Brick 262 out of 1394
# Disintegrating [0, 3, 127]~[0, 4, 127] resting at z=62,62 supporting [] and supported by ['[0, 3, 125]~[0, 5, 125]']
# 0
# Brick 263 out of 1394
# Disintegrating [0, 1, 209]~[3, 1, 209] resting at z=106,106 supporting ['[1, 1, 213]~[1, 3, 213]'] and supported by ['[0, 1, 208]~[4, 1, 208]']
# 31
# Brick 264 out of 1394
# Disintegrating [5, 7, 191]~[5, 8, 191] resting at z=97,97 supporting ['[5, 7, 193]~[9, 7, 193]'] and supported by ['[5, 7, 188]~[5, 9, 188]']
# 17
# Brick 265 out of 1394
# Disintegrating [5, 3, 134]~[5, 6, 134] resting at z=69,69 supporting ['[5, 5, 137]~[5, 5, 140]'] and supported by ['[5, 5, 132]~[7, 5, 132]']
# 1
# Brick 266 out of 1394
# Disintegrating [9, 2, 150]~[9, 2, 152] resting at z=78,80 supporting [] and supported by ['[9, 1, 148]~[9, 3, 148]']
# 0
# Brick 267 out of 1394
# Disintegrating [2, 1, 295]~[4, 1, 295] resting at z=146,146 supporting ['[4, 1, 296]~[4, 4, 296]', '[2, 1, 296]~[2, 1, 298]'] and supported by ['[0, 1, 293]~[3, 1, 293]']
# 16
# Brick 268 out of 1394
# Disintegrating [1, 6, 56]~[1, 7, 56] resting at z=26,26 supporting ['[1, 5, 59]~[1, 7, 59]'] and supported by ['[0, 6, 55]~[2, 6, 55]']
# 1
# Brick 269 out of 1394
# Disintegrating [1, 9, 93]~[5, 9, 93] resting at z=48,48 supporting ['[4, 9, 96]~[5, 9, 96]', '[0, 9, 96]~[2, 9, 96]'] and supported by ['[3, 6, 91]~[3, 9, 91]', '[0, 9, 92]~[1, 9, 92]']
# 3
# Brick 270 out of 1394
# Disintegrating [1, 3, 24]~[4, 3, 24] resting at z=12,12 supporting ['[3, 3, 25]~[3, 5, 25]', '[1, 2, 27]~[1, 4, 27]', '[2, 2, 27]~[2, 4, 27]'] and supported by ['[1, 3, 22]~[1, 3, 22]']
# 1156
# Brick 271 out of 1394
# Disintegrating [5, 1, 133]~[7, 1, 133] resting at z=67,67 supporting [] and supported by ['[3, 1, 132]~[5, 1, 132]']
# 0
# Brick 272 out of 1394
# Disintegrating [6, 8, 175]~[9, 8, 175] resting at z=94,94 supporting ['[7, 7, 178]~[7, 8, 178]', '[3, 8, 176]~[6, 8, 176]', '[9, 8, 178]~[9, 8, 180]'] and supported by ['[7, 6, 174]~[7, 9, 174]']
# 23
# Brick 273 out of 1394
# Disintegrating [0, 8, 272]~[0, 8, 274] resting at z=134,136 supporting [] and supported by ['[0, 5, 270]~[0, 8, 270]']
# 0
# Brick 274 out of 1394
# Disintegrating [0, 7, 14]~[0, 9, 14] resting at z=8,8 supporting ['[0, 5, 16]~[0, 7, 16]', '[0, 8, 16]~[0, 9, 16]'] and supported by ['[0, 7, 13]~[2, 7, 13]']
# 6
# Brick 275 out of 1394
# Disintegrating [1, 7, 297]~[4, 7, 297] resting at z=148,148 supporting ['[2, 7, 300]~[4, 7, 300]'] and supported by ['[2, 6, 296]~[2, 9, 296]']
# 6
# Brick 276 out of 1394
# Disintegrating [8, 5, 68]~[8, 8, 68] resting at z=32,32 supporting ['[8, 8, 69]~[8, 8, 72]', '[8, 4, 69]~[8, 5, 69]'] and supported by ['[8, 4, 66]~[8, 7, 66]']
# 3
# Brick 277 out of 1394
# Disintegrating [2, 0, 247]~[5, 0, 247] resting at z=121,121 supporting ['[0, 0, 251]~[2, 0, 251]'] and supported by ['[1, 0, 246]~[4, 0, 246]']
# 0
# Brick 278 out of 1394
# Disintegrating [7, 2, 3]~[7, 2, 6] resting at z=1,4 supporting [] and supported by []
# 0
# Brick 279 out of 1394
# Disintegrating [0, 7, 247]~[0, 9, 247] resting at z=122,122 supporting [] and supported by ['[0, 6, 246]~[0, 9, 246]']
# 0
# Brick 280 out of 1394
# Disintegrating [4, 0, 288]~[6, 0, 288] resting at z=143,143 supporting [] and supported by ['[5, 0, 285]~[7, 0, 285]']
# 0
# Brick 281 out of 1394
# Disintegrating [4, 6, 71]~[7, 6, 71] resting at z=35,35 supporting ['[7, 6, 74]~[7, 9, 74]'] and supported by ['[7, 3, 70]~[7, 6, 70]']
# 16
# Brick 282 out of 1394
# Disintegrating [4, 1, 57]~[4, 1, 59] resting at z=29,31 supporting [] and supported by ['[4, 1, 56]~[5, 1, 56]']
# 0
# Brick 283 out of 1394
# Disintegrating [2, 1, 92]~[4, 1, 92] resting at z=46,46 supporting ['[4, 0, 95]~[4, 2, 95]', '[3, 0, 94]~[3, 1, 94]'] and supported by ['[4, 0, 90]~[4, 2, 90]']
# 23
# Brick 284 out of 1394
# ...
# Disintegrating [5, 5, 267]~[5, 8, 267] resting at z=131,131 supporting ['[5, 8, 271]~[7, 8, 271]', '[4, 5, 270]~[7, 5, 270]'] and supported by ['[5, 6, 264]~[5, 9, 264]']
# 157
# Brick 1301 out of 1394
# Disintegrating [8, 6, 9]~[8, 7, 9] resting at z=3,3 supporting [] and supported by ['[8, 5, 6]~[8, 7, 6]']
# 0
# Brick 1302 out of 1394
# Disintegrating [2, 7, 141]~[2, 9, 141] resting at z=71,71 supporting [] and supported by ['[2, 6, 138]~[2, 9, 138]']
# 0
# Brick 1303 out of 1394
# Disintegrating [2, 2, 299]~[4, 2, 299] resting at z=148,148 supporting ['[3, 2, 300]~[3, 4, 300]', '[1, 2, 301]~[2, 2, 301]'] and supported by ['[4, 1, 296]~[4, 4, 296]']
# 10
# Brick 1304 out of 1394
# Disintegrating [1, 4, 7]~[1, 6, 7] resting at z=4,4 supporting ['[1, 4, 9]~[1, 7, 9]'] and supported by ['[1, 2, 5]~[1, 5, 5]']
# 3
# Brick 1305 out of 1394
# Disintegrating [8, 9, 131]~[9, 9, 131] resting at z=65,65 supporting ['[9, 8, 134]~[9, 9, 134]'] and supported by ['[4, 9, 128]~[8, 9, 128]']
# 1
# Brick 1306 out of 1394
# Disintegrating [0, 7, 244]~[0, 9, 244] resting at z=120,120 supporting ['[0, 6, 246]~[0, 9, 246]'] and supported by ['[0, 8, 243]~[3, 8, 243]']
# 7
# Brick 1307 out of 1394
# Disintegrating [9, 0, 72]~[9, 3, 72] resting at z=34,34 supporting ['[9, 2, 75]~[9, 2, 76]'] and supported by ['[7, 2, 70]~[9, 2, 70]']
# 2
# Brick 1308 out of 1394
# Disintegrating [3, 9, 273]~[5, 9, 273] resting at z=134,134 supporting ['[3, 9, 275]~[4, 9, 275]'] and supported by ['[3, 9, 272]~[5, 9, 272]']
# 13
# Brick 1309 out of 1394
# Disintegrating [8, 0, 116]~[8, 2, 116] resting at z=62,62 supporting ['[8, 0, 117]~[8, 3, 117]'] and supported by ['[6, 1, 114]~[8, 1, 114]']
# 674
# Brick 1310 out of 1394
# Disintegrating [9, 3, 19]~[9, 5, 19] resting at z=9,9 supporting ['[9, 5, 21]~[9, 7, 21]', '[9, 4, 21]~[9, 4, 24]'] and supported by ['[8, 5, 16]~[9, 5, 16]']
# 4
# Brick 1311 out of 1394
# Disintegrating [5, 5, 78]~[8, 5, 78] resting at z=39,39 supporting ['[8, 4, 81]~[8, 6, 81]'] and supported by ['[3, 5, 75]~[5, 5, 75]']
# 4
# Brick 1312 out of 1394
# Disintegrating [0, 0, 251]~[2, 0, 251] resting at z=122,122 supporting ['[0, 0, 252]~[1, 0, 252]'] and supported by ['[2, 0, 247]~[5, 0, 247]', '[1, 0, 248]~[1, 2, 248]']
# 4
# Brick 1313 out of 1394
# Disintegrating [7, 1, 205]~[9, 1, 205] resting at z=104,104 supporting [] and supported by ['[8, 1, 189]~[8, 1, 191]']
# 0
# Brick 1314 out of 1394
# Disintegrating [3, 3, 23]~[3, 6, 23] resting at z=10,10 supporting [] and supported by ['[2, 3, 20]~[4, 3, 20]']
# 0
# Brick 1315 out of 1394
# Disintegrating [6, 8, 14]~[8, 8, 14] resting at z=9,9 supporting ['[6, 6, 20]~[6, 9, 20]'] and supported by ['[5, 8, 13]~[7, 8, 13]']
# 0
# Brick 1316 out of 1394
# Disintegrating [4, 5, 195]~[4, 7, 195] resting at z=95,95 supporting ['[4, 6, 197]~[4, 7, 197]'] and supported by ['[2, 6, 192]~[4, 6, 192]']
# 1
# Brick 1317 out of 1394
# Disintegrating [0, 9, 299]~[2, 9, 299] resting at z=149,149 supporting [] and supported by ['[0, 9, 298]~[3, 9, 298]']
# 0
# Brick 1318 out of 1394
# Disintegrating [8, 2, 137]~[8, 2, 139] resting at z=72,74 supporting [] and supported by ['[8, 2, 134]~[8, 3, 134]']
# 0
# Brick 1319 out of 1394
# Disintegrating [0, 0, 74]~[0, 2, 74] resting at z=33,33 supporting ['[0, 0, 77]~[0, 2, 77]'] and supported by ['[0, 0, 62]~[2, 0, 62]', '[0, 2, 73]~[0, 3, 73]']
# 6
# Brick 1320 out of 1394
# Disintegrating [5, 9, 47]~[8, 9, 47] resting at z=22,22 supporting ['[6, 9, 49]~[8, 9, 49]'] and supported by ['[4, 9, 45]~[7, 9, 45]']
# 1
# Brick 1321 out of 1394
# Disintegrating [3, 2, 265]~[3, 5, 265] resting at z=129,129 supporting ['[3, 1, 268]~[3, 4, 268]', '[3, 5, 266]~[3, 8, 266]'] and supported by ['[3, 4, 263]~[3, 6, 263]']
# 27
# Brick 1322 out of 1394
# Disintegrating [2, 0, 210]~[4, 0, 210] resting at z=106,106 supporting ['[4, 0, 214]~[7, 0, 214]'] and supported by ['[2, 0, 205]~[2, 0, 207]']
# 5
# Brick 1323 out of 1394
# Disintegrating [3, 6, 129]~[3, 8, 129] resting at z=64,64 supporting [] and supported by ['[3, 6, 127]~[3, 7, 127]']
# 0
# Brick 1324 out of 1394
# Disintegrating [4, 4, 289]~[4, 6, 289] resting at z=142,142 supporting ['[4, 5, 292]~[4, 5, 293]', '[3, 6, 290]~[5, 6, 290]'] and supported by ['[2, 5, 286]~[5, 5, 286]']
# 3
# Brick 1325 out of 1394
# Disintegrating [6, 3, 215]~[8, 3, 215] resting at z=108,108 supporting ['[8, 2, 216]~[8, 3, 216]'] and supported by ['[6, 3, 213]~[8, 3, 213]']
# 1
# Brick 1326 out of 1394
# Disintegrating [0, 2, 15]~[4, 2, 15] resting at z=7,7 supporting ['[0, 2, 18]~[0, 3, 18]', '[2, 1, 17]~[2, 3, 17]', '[3, 2, 17]~[5, 2, 17]', '[1, 2, 16]~[1, 2, 17]'] and supported by ['[3, 2, 12]~[5, 2, 12]', '[1, 2, 14]~[1, 3, 14]']
# 1175
# Brick 1327 out of 1394
# Disintegrating [3, 4, 263]~[3, 6, 263] resting at z=128,128 supporting ['[3, 2, 265]~[3, 5, 265]'] and supported by ['[3, 3, 262]~[3, 5, 262]']
# 28
# Brick 1328 out of 1394
# Disintegrating [5, 5, 215]~[5, 7, 215] resting at z=107,107 supporting ['[4, 5, 218]~[6, 5, 218]', '[4, 7, 218]~[7, 7, 218]'] and supported by ['[3, 6, 212]~[7, 6, 212]']
# 367
# Brick 1329 out of 1394
# Disintegrating [3, 4, 170]~[3, 6, 170] resting at z=85,85 supporting ['[2, 6, 172]~[3, 6, 172]', '[3, 5, 171]~[3, 5, 173]'] and supported by ['[3, 6, 158]~[5, 6, 158]']
# 515
# Brick 1330 out of 1394
# Disintegrating [2, 3, 51]~[5, 3, 51] resting at z=25,25 supporting ['[4, 3, 54]~[4, 4, 54]', '[3, 3, 54]~[3, 3, 56]'] and supported by ['[0, 3, 49]~[3, 3, 49]']
# 2
# Brick 1331 out of 1394
# Disintegrating [1, 4, 37]~[1, 7, 37] resting at z=18,18 supporting ['[1, 5, 40]~[2, 5, 40]'] and supported by ['[0, 5, 36]~[3, 5, 36]']
# 1
# Brick 1332 out of 1394
# Disintegrating [2, 2, 33]~[5, 2, 33] resting at z=16,16 supporting ['[0, 2, 35]~[3, 2, 35]', '[5, 2, 35]~[7, 2, 35]'] and supported by ['[5, 0, 32]~[5, 2, 32]']
# 4
# Brick 1333 out of 1394
# Disintegrating [2, 1, 87]~[5, 1, 87] resting at z=44,44 supporting ['[4, 0, 90]~[4, 2, 90]', '[5, 1, 90]~[6, 1, 90]'] and supported by ['[1, 1, 86]~[3, 1, 86]']
# 26
# Brick 1334 out of 1394
# Disintegrating [0, 5, 251]~[0, 6, 251] resting at z=123,123 supporting [] and supported by ['[0, 3, 248]~[0, 6, 248]']
# 0
# Brick 1335 out of 1394
# Disintegrating [0, 5, 150]~[0, 9, 150] resting at z=73,73 supporting ['[0, 9, 153]~[3, 9, 153]', '[0, 5, 153]~[2, 5, 153]', '[0, 6, 151]~[0, 7, 151]'] and supported by ['[0, 6, 147]~[2, 6, 147]']
# 5
# Brick 1336 out of 1394
# Disintegrating [5, 3, 3]~[8, 3, 3] resting at z=2,2 supporting ['[3, 3, 4]~[6, 3, 4]'] and supported by ['[6, 3, 2]~[6, 5, 2]']
# 12
# Brick 1337 out of 1394
# Disintegrating [1, 6, 207]~[1, 9, 207] resting at z=103,103 supporting ['[1, 8, 210]~[3, 8, 210]', '[1, 4, 210]~[1, 6, 210]', '[0, 9, 210]~[3, 9, 210]'] and supported by ['[1, 8, 205]~[4, 8, 205]']
# 0
# Brick 1338 out of 1394
# Disintegrating [1, 7, 100]~[4, 7, 100] resting at z=51,51 supporting ['[3, 7, 101]~[3, 9, 101]', '[2, 7, 102]~[2, 7, 104]'] and supported by ['[2, 5, 98]~[2, 7, 98]']
# 4
# Brick 1339 out of 1394
# Disintegrating [2, 6, 53]~[5, 6, 53] resting at z=24,24 supporting ['[0, 6, 55]~[2, 6, 55]', '[3, 6, 55]~[6, 6, 55]'] and supported by ['[3, 6, 52]~[3, 8, 52]']
# 1092
# Brick 1340 out of 1394
# Disintegrating [7, 1, 13]~[7, 1, 15] resting at z=5,7 supporting [] and supported by ['[6, 1, 10]~[8, 1, 10]']
# 0
# Brick 1341 out of 1394
# Disintegrating [6, 6, 308]~[6, 7, 308] resting at z=158,158 supporting [] and supported by ['[6, 6, 305]~[6, 6, 307]']
# 0
# Brick 1342 out of 1394
# Disintegrating [3, 4, 103]~[5, 4, 103] resting at z=52,52 supporting ['[5, 2, 107]~[5, 4, 107]', '[3, 4, 104]~[4, 4, 104]'] and supported by ['[4, 4, 100]~[4, 4, 101]']
# 1
# Brick 1343 out of 1394
# Disintegrating [5, 4, 4]~[5, 7, 4] resting at z=2,2 supporting ['[5, 6, 5]~[5, 8, 5]'] and supported by ['[5, 7, 3]~[6, 7, 3]']
# 8
# Brick 1344 out of 1394
# Disintegrating [6, 5, 82]~[6, 6, 82] resting at z=41,41 supporting ['[6, 3, 83]~[6, 5, 83]'] and supported by ['[4, 6, 79]~[6, 6, 79]']
# 5
# Brick 1345 out of 1394
# Disintegrating [8, 1, 124]~[8, 4, 124] resting at z=67,67 supporting [] and supported by ['[8, 2, 118]~[8, 2, 120]']
# 0
# Brick 1346 out of 1394
# Disintegrating [4, 6, 79]~[6, 6, 79] resting at z=40,40 supporting ['[6, 5, 82]~[6, 6, 82]'] and supported by ['[4, 5, 76]~[4, 7, 76]']
# 6
# Brick 1347 out of 1394
# Disintegrating [4, 0, 20]~[4, 1, 20] resting at z=10,10 supporting ['[2, 0, 21]~[5, 0, 21]', '[4, 1, 23]~[7, 1, 23]'] and supported by ['[4, 0, 18]~[4, 2, 18]']
# 3
# Brick 1348 out of 1394
# Disintegrating [8, 4, 169]~[8, 7, 169] resting at z=91,91 supporting ['[6, 6, 172]~[8, 6, 172]', '[7, 4, 170]~[9, 4, 170]'] and supported by ['[7, 4, 166]~[8, 4, 166]', '[8, 6, 166]~[8, 8, 166]']
# 67
# Brick 1349 out of 1394
# Disintegrating [9, 2, 85]~[9, 3, 85] resting at z=43,43 supporting ['[9, 3, 88]~[9, 3, 90]', '[9, 2, 87]~[9, 2, 87]'] and supported by ['[6, 2, 83]~[9, 2, 83]', '[9, 3, 83]~[9, 4, 83]']
# 3
# Brick 1350 out of 1394
# Disintegrating [8, 6, 166]~[8, 8, 166] resting at z=90,90 supporting ['[8, 4, 169]~[8, 7, 169]'] and supported by ['[8, 4, 164]~[8, 6, 164]']
# 0
# Brick 1351 out of 1394
# Disintegrating [0, 2, 243]~[2, 2, 243] resting at z=118,118 supporting ['[1, 2, 245]~[1, 3, 245]'] and supported by ['[2, 0, 240]~[2, 2, 240]']
# 1
# Brick 1352 out of 1394
# Disintegrating [6, 8, 260]~[8, 8, 260] resting at z=125,125 supporting ['[6, 8, 262]~[6, 8, 264]'] and supported by ['[6, 8, 259]~[7, 8, 259]']
# 3
# Brick 1353 out of 1394
# Disintegrating [4, 9, 226]~[6, 9, 226] resting at z=112,112 supporting ['[2, 9, 228]~[4, 9, 228]', '[6, 7, 228]~[6, 9, 228]'] and supported by ['[4, 7, 224]~[4, 9, 224]']
# 4
# Brick 1354 out of 1394
# Disintegrating [1, 2, 150]~[4, 2, 150] resting at z=73,73 supporting ['[3, 2, 153]~[6, 2, 153]'] and supported by ['[3, 0, 149]~[3, 4, 149]', '[2, 2, 147]~[2, 4, 147]']
# 1
# Brick 1355 out of 1394
# Disintegrating [4, 4, 79]~[7, 4, 79] resting at z=39,39 supporting ['[7, 1, 80]~[7, 4, 80]'] and supported by ['[6, 4, 77]~[6, 4, 77]']
# 0
# Brick 1356 out of 1394
# Disintegrating [8, 3, 120]~[8, 4, 120] resting at z=64,64 supporting ['[8, 3, 123]~[8, 5, 123]'] and supported by ['[8, 0, 117]~[8, 3, 117]']
# 2
# Brick 1357 out of 1394
# Disintegrating [3, 0, 94]~[3, 1, 94] resting at z=47,47 supporting ['[3, 1, 98]~[6, 1, 98]', '[1, 0, 97]~[4, 0, 97]'] and supported by ['[2, 1, 92]~[4, 1, 92]']
# 0
# Brick 1358 out of 1394
# Disintegrating [7, 5, 315]~[9, 5, 315] resting at z=160,160 supporting [] and supported by ['[9, 4, 314]~[9, 7, 314]']
# 0
# Brick 1359 out of 1394
# Disintegrating [8, 2, 118]~[8, 2, 120] resting at z=64,66 supporting ['[8, 1, 124]~[8, 4, 124]'] and supported by ['[8, 0, 117]~[8, 3, 117]']
# 1
# Brick 1360 out of 1394
# Disintegrating [3, 4, 104]~[4, 4, 104] resting at z=53,53 supporting [] and supported by ['[3, 4, 103]~[5, 4, 103]']
# 0
# Brick 1361 out of 1394
# Disintegrating [1, 1, 232]~[4, 1, 232] resting at z=114,114 supporting ['[4, 0, 234]~[4, 2, 234]', '[1, 1, 234]~[2, 1, 234]'] and supported by ['[3, 1, 221]~[3, 1, 224]']
# 17
# Brick 1362 out of 1394
# Disintegrating [7, 1, 77]~[7, 2, 77] resting at z=38,38 supporting ['[7, 1, 79]~[9, 1, 79]'] and supported by ['[7, 1, 75]~[7, 3, 75]']
# 1
# Brick 1363 out of 1394
# Disintegrating [1, 4, 159]~[1, 7, 159] resting at z=77,77 supporting ['[1, 7, 161]~[4, 7, 161]', '[1, 2, 162]~[1, 4, 162]'] and supported by ['[1, 6, 157]~[1, 8, 157]']
# 19
# Brick 1364 out of 1394
# Disintegrating [8, 4, 25]~[8, 6, 25] resting at z=13,13 supporting [] and supported by ['[8, 6, 23]~[8, 7, 23]']
# 0
# Brick 1365 out of 1394
# Disintegrating [4, 9, 97]~[4, 9, 99] resting at z=50,52 supporting [] and supported by ['[4, 9, 96]~[5, 9, 96]']
# 0
# Brick 1366 out of 1394
# Disintegrating [2, 6, 192]~[4, 6, 192] resting at z=94,94 supporting ['[4, 5, 195]~[4, 7, 195]', '[3, 6, 193]~[3, 6, 196]', '[0, 6, 195]~[2, 6, 195]'] and supported by ['[1, 6, 189]~[4, 6, 189]']
# 414
# Brick 1367 out of 1394
# Disintegrating [6, 1, 118]~[6, 1, 119] resting at z=63,64 supporting ['[6, 1, 122]~[6, 2, 122]'] and supported by ['[5, 1, 116]~[7, 1, 116]']
# 1
# Brick 1368 out of 1394
# Disintegrating [4, 5, 253]~[4, 5, 255] resting at z=122,124 supporting ['[2, 5, 256]~[4, 5, 256]'] and supported by ['[4, 3, 251]~[4, 6, 251]']
# 239
# Brick 1369 out of 1394
# Disintegrating [9, 0, 266]~[9, 3, 266] resting at z=127,127 supporting ['[8, 1, 269]~[9, 1, 269]', '[7, 0, 268]~[9, 0, 268]'] and supported by ['[9, 2, 262]~[9, 2, 263]']
# 5
# Brick 1370 out of 1394
# Disintegrating [2, 1, 153]~[2, 1, 154] resting at z=74,75 supporting [] and supported by ['[1, 1, 150]~[3, 1, 150]']
# 0
# Brick 1371 out of 1394
# Disintegrating [2, 7, 3]~[4, 7, 3] resting at z=1,1 supporting ['[2, 7, 6]~[4, 7, 6]'] and supported by []
# 6
# Brick 1372 out of 1394
# Disintegrating [8, 1, 291]~[8, 2, 291] resting at z=147,147 supporting [] and supported by ['[8, 2, 289]~[8, 4, 289]']
# 0
# Brick 1373 out of 1394
# Disintegrating [0, 2, 206]~[0, 4, 206] resting at z=102,102 supporting ['[0, 3, 208]~[0, 3, 210]', '[0, 4, 208]~[0, 4, 208]'] and supported by ['[0, 1, 205]~[0, 3, 205]']
# 2
# Brick 1374 out of 1394
# Disintegrating [0, 2, 73]~[0, 3, 73] resting at z=32,32 supporting ['[0, 0, 74]~[0, 2, 74]'] and supported by ['[0, 3, 71]~[0, 6, 71]']
# 0
# Brick 1375 out of 1394
# Disintegrating [2, 7, 15]~[2, 9, 15] resting at z=8,8 supporting ['[2, 7, 18]~[2, 9, 18]'] and supported by ['[0, 7, 13]~[2, 7, 13]']
# 5
# Brick 1376 out of 1394
# Disintegrating [7, 2, 28]~[7, 4, 28] resting at z=13,13 supporting ['[7, 2, 31]~[7, 4, 31]'] and supported by ['[7, 1, 25]~[7, 3, 25]']
# 1
# Brick 1377 out of 1394
# Disintegrating [6, 1, 10]~[8, 1, 10] resting at z=4,4 supporting ['[7, 1, 13]~[7, 1, 15]'] and supported by ['[6, 1, 7]~[6, 1, 7]']
# 1
# Brick 1378 out of 1394
# Disintegrating [0, 1, 293]~[3, 1, 293] resting at z=145,145 supporting ['[1, 1, 294]~[1, 3, 294]', '[0, 1, 294]~[0, 1, 295]', '[2, 1, 295]~[4, 1, 295]'] and supported by ['[1, 0, 291]~[1, 2, 291]']
# 19
# Brick 1379 out of 1394
# Disintegrating [1, 1, 20]~[2, 1, 20] resting at z=9,9 supporting [] and supported by ['[2, 1, 17]~[2, 3, 17]']
# 0
# Brick 1380 out of 1394
# Disintegrating [2, 4, 289]~[2, 7, 289] resting at z=142,142 supporting ['[2, 7, 291]~[2, 7, 293]', '[0, 6, 291]~[2, 6, 291]', '[2, 3, 290]~[2, 4, 290]'] and supported by ['[2, 5, 286]~[5, 5, 286]']
# 18
# Brick 1381 out of 1394
# Disintegrating [4, 1, 317]~[7, 1, 317] resting at z=161,161 supporting ['[3, 1, 318]~[4, 1, 318]', '[6, 1, 318]~[8, 1, 318]'] and supported by ['[7, 1, 316]~[7, 3, 316]']
# 4
# Brick 1382 out of 1394
# Disintegrating [0, 6, 87]~[0, 9, 87] resting at z=45,45 supporting ['[0, 4, 89]~[0, 6, 89]'] and supported by ['[0, 7, 86]~[3, 7, 86]']
# 1
# Brick 1383 out of 1394
# Disintegrating [6, 1, 7]~[6, 1, 7] resting at z=3,3 supporting ['[6, 1, 10]~[8, 1, 10]'] and supported by ['[5, 1, 4]~[7, 1, 4]']
# 2
# Brick 1384 out of 1394
# Disintegrating [7, 6, 254]~[7, 7, 254] resting at z=124,124 supporting ['[6, 7, 260]~[8, 7, 260]'] and supported by ['[5, 6, 253]~[7, 6, 253]']
# 9
# Brick 1385 out of 1394
# Disintegrating [3, 3, 6]~[3, 3, 6] resting at z=4,4 supporting ['[3, 3, 8]~[3, 3, 10]'] and supported by ['[3, 3, 4]~[6, 3, 4]']
# 1
# Brick 1386 out of 1394
# Disintegrating [7, 1, 102]~[7, 3, 102] resting at z=52,52 supporting ['[7, 1, 104]~[7, 1, 107]'] and supported by ['[7, 2, 100]~[7, 4, 100]']
# 682
# Brick 1387 out of 1394
# Disintegrating [4, 3, 147]~[6, 3, 147] resting at z=76,76 supporting ['[3, 3, 151]~[6, 3, 151]'] and supported by ['[6, 3, 138]~[6, 3, 140]']
# 8
# Brick 1388 out of 1394
# Disintegrating [7, 0, 137]~[7, 0, 141] resting at z=69,73 supporting [] and supported by ['[4, 0, 135]~[7, 0, 135]']
# 0
# Brick 1389 out of 1394
# Disintegrating [1, 2, 27]~[1, 4, 27] resting at z=13,13 supporting ['[0, 4, 28]~[2, 4, 28]', '[0, 3, 29]~[2, 3, 29]'] and supported by ['[1, 3, 24]~[4, 3, 24]']
# 0
# Brick 1390 out of 1394
# Disintegrating [6, 9, 49]~[8, 9, 49] resting at z=23,23 supporting [] and supported by ['[5, 9, 47]~[8, 9, 47]']
# 0
# Brick 1391 out of 1394
# Disintegrating [5, 0, 2]~[5, 0, 3] resting at z=1,2 supporting [] and supported by []
# 0
# Brick 1392 out of 1394
# Disintegrating [1, 6, 172]~[1, 6, 175] resting at z=83,86 supporting [] and supported by ['[1, 4, 169]~[1, 7, 169]']
# 0
# Brick 1393 out of 1394
# Disintegrating [0, 5, 302]~[0, 5, 305] resting at z=151,154 supporting [] and supported by ['[0, 5, 301]~[3, 5, 301]']
# 0
# 79042
