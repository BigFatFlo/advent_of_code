# %%
from queue import PriorityQueue
from tabulate import tabulate
from dataclasses import dataclass, field

f = open("input.txt", "r")

grid = []

for line in f:
    grid.append([int(c) for c in line.replace("\n", '') if c != ''])

height = len(grid)
width = len(grid[0])

visited_nodes = [[0 for j in range(width)] for i in range(height)]

class Node:
    def __init__(self, prev, coords, dir, dir_steps) -> None:
        self.prev = prev
        self.coords = coords
        self.dir = dir
        self.dir_steps = dir_steps

@dataclass(order=True)
class PrioritizedItem:
    heat_loss: int
    node: Node=field(compare=False)

    def __init__(self, heat_loss, node):
        self.heat_loss = heat_loss
        self.node = node

starting_node = PrioritizedItem(0, Node(None, (0, 0), 'r', 0))

nodes = PriorityQueue()
nodes.put(starting_node)
final_node = starting_node
seen_nodes = set()

while not nodes.empty():
    item = nodes.get()
    heat_loss = item.heat_loss
    node = item.node
    (i, j) = node.coords
    dir = node.dir
    dir_steps = node.dir_steps
    if ((i, j), dir, dir_steps) in seen_nodes:
        continue
    seen_nodes.add(((i, j), dir, dir_steps))
    visited_nodes[i][j] += 1
    # print(tabulate(visited_nodes))
    if (i, j) == (0, 0) and heat_loss == 0:
        new_heat_loss = 0
    else:
        new_heat_loss = heat_loss + grid[i][j]
    if (i, j) == (height-1, width-1):
        final_node = PrioritizedItem(new_heat_loss, node)
        break

    match dir:
        case 'r':
            if i-1 >= 0:
                new_dir = 'u'
                new_coords = (i-1, j)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i+1 < height:
                new_dir = 'd'
                new_coords = (i+1, j)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j+1 < width and dir_steps < 3:
                new_dir = 'r'
                new_coords = (i, j+1)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'l':
            if i-1 >= 0:
                new_dir = 'u'
                new_coords = (i-1, j)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i+1 < height:
                new_dir = 'd'
                new_coords = (i+1, j)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j-1 >= 0 and dir_steps < 3:
                new_dir = 'l'
                new_coords = (i, j-1)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'u':
            if j-1 >= 0:
                new_dir = 'l'
                new_coords = (i, j-1)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j+1 < width:
                new_dir = 'r'
                new_coords = (i, j+1)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i-1 >= 0 and dir_steps < 3:
                new_dir = 'u'
                new_coords = (i-1, j)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'd':
            if j-1 >= 0:
                new_dir = 'l'
                new_coords = (i, j-1)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j+1 < width:
                new_dir = 'r'
                new_coords = (i, j+1)
                new_dir_steps = 1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i+1 < height and dir_steps < 3:
                new_dir = 'd'
                new_coords = (i+1, j)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))

print(final_node.heat_loss)
print(final_node)
# Out:
# 967
# PrioritizedItem(heat_loss=967, node=<__main__.Node object at 0x1102ea750>)

# %%
from queue import PriorityQueue
from tabulate import tabulate
from dataclasses import dataclass, field

f = open("input.txt", "r")

grid = []

for line in f:
    grid.append([int(c) for c in line.replace("\n", '') if c != ''])

height = len(grid)
width = len(grid[0])

visited_nodes = [[0 for j in range(width)] for i in range(height)]

class Node:
    def __init__(self, prev, coords, dir, dir_steps) -> None:
        self.prev = prev
        self.coords = coords
        self.dir = dir
        self.dir_steps = dir_steps

@dataclass(order=True)
class PrioritizedItem:
    heat_loss: int
    node: Node=field(compare=False)

    def __init__(self, heat_loss, node):
        self.heat_loss = heat_loss
        self.node = node

starting_node = PrioritizedItem(0, Node(None, (0, 0), 'r', 0))

nodes = PriorityQueue()
nodes.put(starting_node)
final_node = starting_node
seen_nodes = set()

while not nodes.empty():
    item = nodes.get()
    heat_loss = item.heat_loss
    node = item.node
    (i, j) = node.coords
    dir = node.dir
    dir_steps = node.dir_steps
    if ((i, j), dir, dir_steps) in seen_nodes:
        continue
    seen_nodes.add(((i, j), dir, dir_steps))
    visited_nodes[i][j] += 1
    # print(tabulate(visited_nodes))
    if (i, j) == (0, 0) and heat_loss == 0:
        new_heat_loss = 0
    else:
        new_heat_loss = heat_loss + grid[i][j]
    if (i, j) == (height-1, width-1) and dir_steps >= 4:
        final_node = PrioritizedItem(new_heat_loss, node)
        break

    match dir:
        case 'r':
            if dir_steps >= 4:
                if i-1 >= 0:
                    new_dir = 'u'
                    new_coords = (i-1, j)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
                if i+1 < height:
                    new_dir = 'd'
                    new_coords = (i+1, j)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j+1 < width and dir_steps < 10:
                new_dir = 'r'
                new_coords = (i, j+1)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'l':
            if dir_steps >= 4:
                if i-1 >= 0:
                    new_dir = 'u'
                    new_coords = (i-1, j)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
                if i+1 < height:
                    new_dir = 'd'
                    new_coords = (i+1, j)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if j-1 >= 0 and dir_steps < 10:
                new_dir = 'l'
                new_coords = (i, j-1)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'u':
            if dir_steps >= 4:
                if j-1 >= 0:
                    new_dir = 'l'
                    new_coords = (i, j-1)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
                if j+1 < width:
                    new_dir = 'r'
                    new_coords = (i, j+1)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i-1 >= 0 and dir_steps < 10:
                new_dir = 'u'
                new_coords = (i-1, j)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
        case 'd':
            if dir_steps >= 4:
                if j-1 >= 0:
                    new_dir = 'l'
                    new_coords = (i, j-1)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
                if j+1 < width:
                    new_dir = 'r'
                    new_coords = (i, j+1)
                    new_dir_steps = 1
                    nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))
            if i+1 < height and dir_steps < 10:
                new_dir = 'd'
                new_coords = (i+1, j)
                new_dir_steps = dir_steps+1
                nodes.put(PrioritizedItem(new_heat_loss, Node(node, new_coords, new_dir, new_dir_steps)))

print(final_node.heat_loss)
print(final_node)
# Out:
# 1101
# PrioritizedItem(heat_loss=1101, node=<__main__.Node object at 0x110f3fdd0>)
